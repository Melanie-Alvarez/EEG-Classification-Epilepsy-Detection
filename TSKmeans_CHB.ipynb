# %%
# !pip install mne
# !pip install tslearn
# Out:
# Requirement already satisfied: mne in /usr/local/lib/python3.10/dist-packages (1.9.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from mne) (4.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from mne) (3.1.4)
# Requirement already satisfied: lazy-loader>=0.3 in /usr/local/lib/python3.10/dist-packages (from mne) (0.4)
# Requirement already satisfied: matplotlib>=3.6 in /usr/local/lib/python3.10/dist-packages (from mne) (3.7.1)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.10/dist-packages (from mne) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from mne) (24.1)
# Requirement already satisfied: pooch>=1.5 in /usr/local/lib/python3.10/dist-packages (from mne) (1.8.2)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.10/dist-packages (from mne) (1.13.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from mne) (4.66.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->mne) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->mne) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->mne) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->mne) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->mne) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->mne) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->mne) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.5->mne) (4.3.6)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.5->mne) (2.32.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->mne) (2.1.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.6->mne) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2024.8.30)
# Requirement already satisfied: tslearn in /usr/local/lib/python3.10/dist-packages (0.6.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from tslearn) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from tslearn) (1.13.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from tslearn) (1.5.2)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from tslearn) (0.60.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from tslearn) (1.4.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->tslearn) (0.43.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->tslearn) (3.5.0)

# %%
# !pip install pyedflib
# Out:
# Requirement already satisfied: pyedflib in /usr/local/lib/python3.10/dist-packages (0.1.40)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from pyedflib) (1.26.4)

# %% [markdown]
# # Ubicarse en la ruta de la DGX

# %%
import os

# Cambia esta ruta por la que tú necesites
ruta = '/mnt/DGX0Raid/databases/CHB_data/CHB'
os.chdir(ruta)

# Verifica que estás en el directorio correcto
print("Directorio actual:", os.getcwd())
# Out:
# Directorio actual: /mnt/DGX0Raid/databases/CHB_data/CHB

# %%
import glob
import re

def extraer_duraciones_archivo(ruta_archivo):
    """Extrae las duraciones de seizure de un archivo."""
    duraciones = []
    with open(ruta_archivo, "r") as archivo:
        lineas = archivo.readlines()
        # Recorremos cada línea para encontrar el inicio y fin del seizure
        for i, linea in enumerate(lineas):
            if "Start Time:" in linea and "Seizure" in linea:
                inicio = re.search(r"Start Time:\s*(\d+)", linea)
                # Buscamos en la siguiente línea el tiempo de finalización
                if inicio and i + 1 < len(lineas) and "End Time:" in lineas[i + 1] and "Seizure" in lineas[i + 1]:
                    fin = re.search(r"End Time:\s*(\d+)", lineas[i + 1])
                    if fin:
                        inicio_t = int(inicio.group(1))
                        fin_t = int(fin.group(1))
                        duracion = fin_t - inicio_t
                        # Imprimir los valores de inicio, fin y duración calculada
                        print(f"Start Time: {inicio_t} - End Time: {fin_t} -> Duración: {duracion} segundos")
                        duraciones.append(duracion)
    return duraciones

def obtener_maxima_duracion(patron_archivos):
    """
    Busca en todos los archivos que cumplan el patrón, imprime las duraciones de cada seizure episode,
    el número de seizures por archivo y el total de duraciones encontradas, devolviendo la mayor duración.
    """
    max_duracion = 0
    total_duraciones = 0
    # Obtenemos la lista de archivos que coincidan con el patrón
    lista_archivos = glob.glob(patron_archivos)

    for archivo in lista_archivos:
        print(f"\nProcesando archivo: {archivo}")
        duraciones = extraer_duraciones_archivo(archivo)
        total_duraciones += len(duraciones)
        if duraciones:
            print("Número de seizures en el archivo", archivo, ":", len(duraciones))
            max_archivo = max(duraciones)
            if max_archivo > max_duracion:
                max_duracion = max_archivo

    print("\nTotal de archivos procesados:", len(lista_archivos))
    print("Número total de duraciones encontradas:", total_duraciones)
    return max_duracion

# Uso del código:
if __name__ == "__main__":
    # Asumiendo que los archivos tienen extensión .txt y se encuentran en el directorio especificado
    patron = "/mnt/DGX0Raid/databases/CHB_data/txt_Files/*.txt"
    duracion_max = obtener_maxima_duracion(patron)
    print("\nLa mayor duración de un seizure episode es:", duracion_max, "segundos")
# Out:
# Procesando archivo: /mnt/DGX0Raid/databases/CHB_data/txt_Files/chb14-summary.txt
# Start Time: 1986 - End Time: 2000 -> Duración: 14 segundos
# Start Time: 1372 - End Time: 1392 -> Duración: 20 segundos
# Start Time: 2817 - End Time: 2839 -> Duración: 22 segundos
# Start Time: 1911 - End Time: 1925 -> Duración: 14 segundos
# Start Time: 1838 - End Time: 1879 -> Duración: 41 segundos
# Start Time: 3239 - End Time: 3259 -> Duración: 20 segundos
# Start Time: 1039 - End Time: 1061 -> Duración: 22 segundos
# Start Time: 2833 - End Time: 2849 -> Duración: 16 segundos
# Número de seizures en el archivo /mnt/DGX0Raid/databases/CHB_data/txt_Files/chb14-summary.txt : 8
#
# Procesando archivo: /mnt/DGX0Raid/databases/CHB_data/txt_Files/chb09-summary.txt
# Start Time: 12231 - End Time: 12295 -> Duración: 64 segundos
# Start Time: 2951 - End Time: 3030 -> Duración: 79 segundos
# Start Time: 9196 - End Time: 9267 -> Duración: 71 segundos
# Start Time: 5299 - End Time: 5361 -> Duración: 62 segundos
# Número de seizures en el archivo /mnt/DGX0Raid/databases/CHB_data/txt_Files/chb09-summary.txt : 4
#
# Procesando archivo: /mnt/DGX0Raid/databases/CHB_data/txt_Files/chb11-summary.txt
# Start Time: 298 - End Time: 320 -> Duración: 22 segundos
# Start Time: 2695 - End Time: 2727 -> Duración: 32 segundos
# Start Time: 1454 - End Time: 2206 -> Duración: 752 segundos
# Número de seizures en el archivo /mnt/DGX0Raid/databases/CHB_data/txt_Files/chb11-summary.txt : 3
#
# Procesando archivo: /mnt/DGX0Raid/databases/CHB_data/txt_Files/chb02-summary.txt
# Start Time: 130 - End Time: 212 -> Duración: 82 segundos
# Start Time: 2972 - End Time: 3053 -> Duración: 81 segundos
# Start Time: 3369 - End Time: 3378 -> Duración: 9 segundos
# Número de seizures en el archivo /mnt/DGX0Raid/databases/CHB_data/txt_Files/chb02-summary.txt : 3
#
# Procesando archivo: /mnt/DGX0Raid/databases/CHB_data/txt_Files/chb07-summary.txt
# Start Time: 4920 - End Time: 5006 -> Duración: 86 segundos
# Start Time: 3285 - End Time: 3381 -> Duración: 96 segundos
# Start Time: 13688 - End Time: 13831 -> Duración: 143 segundos
# Número de seizures en el archivo /mnt/DGX0Raid/databases/CHB_data/txt_Files/chb07-summary.txt : 3
#
# Procesando archivo: /mnt/DGX0Raid/databases/CHB_data/txt_Files/chb13-summary.txt
# Start Time: 2077 - End Time: 2121 -> Duración: 44 segundos
# Start Time: 934 - End Time: 1004 -> Duración: 70 segundos
# Start Time: 142 - End Time: 173 -> Duración: 31 segundos
# Start Time: 530 - End Time: 594 -> Duración: 64 segundos
# Start Time: 458 - End Time: 478 -> Duración: 20 segundos
# Start Time: 2436 - End Time: 2454 -> Duración: 18 segundos
# Start Time: 2474 - End Time: 2491 -> Duración: 17 segundos
# Start Time: 3339 - End Time: 3401 -> Duración: 62 segundos
# Start Time: 638 - End Time: 660 -> Duración: 22 segundos
# Start Time: 851 - End Time: 916 -> Duración: 65 segundos
# Start Time: 1626 - End Time: 1691 -> Duración: 65 segundos
# Start Time: 2664 - End Time: 2721 -> Duración: 57 segundos
# Número de seizures en el archivo /mnt/DGX0Raid/databases/CHB_data/txt_Files/chb13-summary.txt : 12
#
# Procesando archivo: /mnt/DGX0Raid/databases/CHB_data/txt_Files/chb21-summary.txt
# Start Time: 1288 - End Time: 1344 -> Duración: 56 segundos
# Start Time: 2627 - End Time: 2677 -> Duración: 50 segundos
# Start Time: 2003 - End Time: 2084 -> Duración: 81 segundos
# Start Time: 2553 - End Time: 2565 -> Duración: 12 segundos
# Número de seizures en el archivo /mnt/DGX0Raid/databases/CHB_data/txt_Files/chb21-summary.txt : 4
#
# Procesando archivo: /mnt/DGX0Raid/databases/CHB_data/txt_Files/chb20-summary.txt
# Start Time: 94 - End Time: 123 -> Duración: 29 segundos
# Start Time: 1440 - End Time: 1470 -> Duración: 30 segundos
# Start Time: 2498 - End Time: 2537 -> Duración: 39 segundos
# Start Time: 1971 - End Time: 2009 -> Duración: 38 segundos
# Start Time: 390 - End Time: 425 -> Duración: 35 segundos
# Start Time: 1689 - End Time: 1738 -> Duración: 49 segundos
# Start Time: 2226 - End Time: 2261 -> Duración: 35 segundos
# Start Time: 1393 - End Time: 1432 -> Duración: 39 segundos
# Número de seizures en el archivo /mnt/DGX0Raid/databases/CHB_data/txt_Files/chb20-summary.txt : 8
#
# Procesando archivo: /mnt/DGX0Raid/databases/CHB_data/txt_Files/chb10-summary.txt
# Start Time: 6313 - End Time: 6348 -> Duración: 35 segundos
# Start Time: 6888 - End Time: 6958 -> Duración: 70 segundos
# Start Time: 2382 - End Time: 2447 -> Duración: 65 segundos
# Start Time: 3021 - End Time: 3079 -> Duración: 58 segundos
# Start Time: 3801 - End Time: 3877 -> Duración: 76 segundos
# Start Time: 4618 - End Time: 4707 -> Duración: 89 segundos
# Start Time: 1383 - End Time: 1437 -> Duración: 54 segundos
# Número de seizures en el archivo /mnt/DGX0Raid/databases/CHB_data/txt_Files/chb10-summary.txt : 7
#
# Procesando archivo: /mnt/DGX0Raid/databases/CHB_data/txt_Files/chb01-summary.txt
# Start Time: 2996 - End Time: 3036 -> Duración: 40 segundos
# Start Time: 1467 - End Time: 1494 -> Duración: 27 segundos
# Start Time: 1732 - End Time: 1772 -> Duración: 40 segundos
# Start Time: 1015 - End Time: 1066 -> Duración: 51 segundos
# Start Time: 1720 - End Time: 1810 -> Duración: 90 segundos
# Start Time: 327 - End Time: 420 -> Duración: 93 segundos
# Start Time: 1862 - End Time: 1963 -> Duración: 101 segundos
# Número de seizures en el archivo /mnt/DGX0Raid/databases/CHB_data/txt_Files/chb01-summary.txt : 7
#
# Procesando archivo: /mnt/DGX0Raid/databases/CHB_data/txt_Files/chb22-summary.txt
# Start Time: 3367 - End Time: 3425 -> Duración: 58 segundos
# Start Time: 3139 - End Time: 3213 -> Duración: 74 segundos
# Start Time: 1263 - End Time: 1335 -> Duración: 72 segundos
# Número de seizures en el archivo /mnt/DGX0Raid/databases/CHB_data/txt_Files/chb22-summary.txt : 3
#
# Procesando archivo: /mnt/DGX0Raid/databases/CHB_data/txt_Files/chb23-summary.txt
# Start Time: 3962 - End Time: 4075 -> Duración: 113 segundos
# Start Time: 325 - End Time: 345 -> Duración: 20 segundos
# Start Time: 5104 - End Time: 5151 -> Duración: 47 segundos
# Start Time: 2589 - End Time: 2660 -> Duración: 71 segundos
# Start Time: 6885 - End Time: 6947 -> Duración: 62 segundos
# Start Time: 8505 - End Time: 8532 -> Duración: 27 segundos
# Start Time: 9580 - End Time: 9664 -> Duración: 84 segundos
# Número de seizures en el archivo /mnt/DGX0Raid/databases/CHB_data/txt_Files/chb23-summary.txt : 7
#
# Procesando archivo: /mnt/DGX0Raid/databases/CHB_data/txt_Files/chb18-summary.txt
# Start Time: 3477 - End Time: 3527 -> Duración: 50 segundos
# Start Time: 541 - End Time: 571 -> Duración: 30 segundos
# Start Time: 2087 - End Time: 2155 -> Duración: 68 segundos
# Start Time: 1908 - End Time: 1963 -> Duración: 55 segundos
# Start Time: 2196 - End Time: 2264 -> Duración: 68 segundos
# Start Time: 463 - End Time: 509 -> Duración: 46 segundos
# Número de seizures en el archivo /mnt/DGX0Raid/databases/CHB_data/txt_Files/chb18-summary.txt : 6
#
# Procesando archivo: /mnt/DGX0Raid/databases/CHB_data/txt_Files/chb17-summary.txt
# Start Time: 2282 - End Time: 2372 -> Duración: 90 segundos
# Start Time: 3025 - End Time: 3140 -> Duración: 115 segundos
# Start Time: 3136 - End Time: 3224 -> Duración: 88 segundos
# Número de seizures en el archivo /mnt/DGX0Raid/databases/CHB_data/txt_Files/chb17-summary.txt : 3
#
# Procesando archivo: /mnt/DGX0Raid/databases/CHB_data/txt_Files/chb12-summary.txt
# Start Time: 1665 - End Time: 1726 -> Duración: 61 segundos
# Start Time: 3415 - End Time: 3447 -> Duración: 32 segundos
# Start Time: 1426 - End Time: 1439 -> Duración: 13 segundos
# Start Time: 1591 - End Time: 1614 -> Duración: 23 segundos
# Start Time: 1957 - End Time: 1977 -> Duración: 20 segundos
# Start Time: 2798 - End Time: 2824 -> Duración: 26 segundos
# Start Time: 3082 - End Time: 3114 -> Duración: 32 segundos
# Start Time: 3503 - End Time: 3535 -> Duración: 32 segundos
# Start Time: 593 - End Time: 625 -> Duración: 32 segundos
# Start Time: 811 - End Time: 856 -> Duración: 45 segundos
# Start Time: 1085 - End Time: 1122 -> Duración: 37 segundos
# Start Time: 253 - End Time: 333 -> Duración: 80 segundos
# Start Time: 425 - End Time: 522 -> Duración: 97 segundos
# Start Time: 630 - End Time: 670 -> Duración: 40 segundos
# Start Time: 916 - End Time: 951 -> Duración: 35 segundos
# Start Time: 1097 - End Time: 1124 -> Duración: 27 segundos
# Start Time: 1728 - End Time: 1753 -> Duración: 25 segundos
# Start Time: 1921 - End Time: 1963 -> Duración: 42 segundos
# Start Time: 2388 - End Time: 2440 -> Duración: 52 segundos
# Start Time: 2621 - End Time: 2669 -> Duración: 48 segundos
# Start Time: 181 - End Time: 215 -> Duración: 34 segundos
# Start Time: 107 - End Time: 146 -> Duración: 39 segundos
# Start Time: 554 - End Time: 592 -> Duración: 38 segundos
# Start Time: 1163 - End Time: 1199 -> Duración: 36 segundos
# Start Time: 1401 - End Time: 1447 -> Duración: 46 segundos
# Start Time: 1884 - End Time: 1921 -> Duración: 37 segundos
# Start Time: 3557 - End Time: 3584 -> Duración: 27 segundos
# Start Time: 2185 - End Time: 2206 -> Duración: 21 segundos
# Start Time: 2427 - End Time: 2450 -> Duración: 23 segundos
# Start Time: 653 - End Time: 680 -> Duración: 27 segundos
# Start Time: 1548 - End Time: 1573 -> Duración: 25 segundos
# Start Time: 2798 - End Time: 2821 -> Duración: 23 segundos
# Start Time: 2966 - End Time: 3009 -> Duración: 43 segundos
# Start Time: 3146 - End Time: 3201 -> Duración: 55 segundos
# Start Time: 3364 - End Time: 3410 -> Duración: 46 segundos
# Start Time: 699 - End Time: 750 -> Duración: 51 segundos
# Start Time: 945 - End Time: 973 -> Duración: 28 segundos
# Start Time: 1170 - End Time: 1199 -> Duración: 29 segundos
# Start Time: 1676 - End Time: 1701 -> Duración: 25 segundos
# Start Time: 2213 - End Time: 2236 -> Duración: 23 segundos
# Número de seizures en el archivo /mnt/DGX0Raid/databases/CHB_data/txt_Files/chb12-summary.txt : 40
#
# Procesando archivo: /mnt/DGX0Raid/databases/CHB_data/txt_Files/chb08-summary.txt
# Start Time: 2670 - End Time: 2841 -> Duración: 171 segundos
# Start Time: 2856 - End Time: 3046 -> Duración: 190 segundos
# Start Time: 2988 - End Time: 3122 -> Duración: 134 segundos
# Start Time: 2417 - End Time: 2577 -> Duración: 160 segundos
# Start Time: 2083 - End Time: 2347 -> Duración: 264 segundos
# Número de seizures en el archivo /mnt/DGX0Raid/databases/CHB_data/txt_Files/chb08-summary.txt : 5
#
# Procesando archivo: /mnt/DGX0Raid/databases/CHB_data/txt_Files/chb03-summary.txt
# Start Time: 362 - End Time: 414 -> Duración: 52 segundos
# Start Time: 731 - End Time: 796 -> Duración: 65 segundos
# Start Time: 432 - End Time: 501 -> Duración: 69 segundos
# Start Time: 2162 - End Time: 2214 -> Duración: 52 segundos
# Start Time: 1982 - End Time: 2029 -> Duración: 47 segundos
# Start Time: 2592 - End Time: 2656 -> Duración: 64 segundos
# Start Time: 1725 - End Time: 1778 -> Duración: 53 segundos
# Número de seizures en el archivo /mnt/DGX0Raid/databases/CHB_data/txt_Files/chb03-summary.txt : 7
#
# Procesando archivo: /mnt/DGX0Raid/databases/CHB_data/txt_Files/chb15-summary.txt
# Start Time: 272 - End Time: 397 -> Duración: 125 segundos
# Start Time: 1082 - End Time: 1113 -> Duración: 31 segundos
# Start Time: 1591 - End Time: 1748 -> Duración: 157 segundos
# Start Time: 1925 - End Time: 1960 -> Duración: 35 segundos
# Start Time: 607 - End Time: 662 -> Duración: 55 segundos
# Start Time: 760 - End Time: 965 -> Duración: 205 segundos
# Start Time: 876 - End Time: 1066 -> Duración: 190 segundos
# Start Time: 1751 - End Time: 1871 -> Duración: 120 segundos
# Start Time: 834 - End Time: 894 -> Duración: 60 segundos
# Start Time: 2378 - End Time: 2497 -> Duración: 119 segundos
# Start Time: 3362 - End Time: 3425 -> Duración: 63 segundos
# Start Time: 3322 - End Time: 3429 -> Duración: 107 segundos
# Start Time: 1108 - End Time: 1248 -> Duración: 140 segundos
# Start Time: 778 - End Time: 849 -> Duración: 71 segundos
# Start Time: 263 - End Time: 318 -> Duración: 55 segundos
# Start Time: 843 - End Time: 1020 -> Duración: 177 segundos
# Start Time: 1524 - End Time: 1595 -> Duración: 71 segundos
# Start Time: 2179 - End Time: 2250 -> Duración: 71 segundos
# Start Time: 3428 - End Time: 3460 -> Duración: 32 segundos
# Start Time: 751 - End Time: 859 -> Duración: 108 segundos
# Número de seizures en el archivo /mnt/DGX0Raid/databases/CHB_data/txt_Files/chb15-summary.txt : 20
#
# Procesando archivo: /mnt/DGX0Raid/databases/CHB_data/txt_Files/chb19-summary.txt
# Start Time: 299 - End Time: 377 -> Duración: 78 segundos
# Start Time: 2964 - End Time: 3041 -> Duración: 77 segundos
# Start Time: 3159 - End Time: 3240 -> Duración: 81 segundos
# Número de seizures en el archivo /mnt/DGX0Raid/databases/CHB_data/txt_Files/chb19-summary.txt : 3
#
# Procesando archivo: /mnt/DGX0Raid/databases/CHB_data/txt_Files/chb04-summary.txt
# Start Time: 7804 - End Time: 7853 -> Duración: 49 segundos
# Start Time: 6446 - End Time: 6557 -> Duración: 111 segundos
# Start Time: 1679 - End Time: 1781 -> Duración: 102 segundos
# Start Time: 3782 - End Time: 3898 -> Duración: 116 segundos
# Número de seizures en el archivo /mnt/DGX0Raid/databases/CHB_data/txt_Files/chb04-summary.txt : 4
#
# Procesando archivo: /mnt/DGX0Raid/databases/CHB_data/txt_Files/chb06-summary.txt
# Start Time: 1724 - End Time: 1738 -> Duración: 14 segundos
# Start Time: 7461 - End Time: 7476 -> Duración: 15 segundos
# Start Time: 13525 - End Time: 13540 -> Duración: 15 segundos
# Start Time: 327 - End Time: 347 -> Duración: 20 segundos
# Start Time: 6211 - End Time: 6231 -> Duración: 20 segundos
# Start Time: 12500 - End Time: 12516 -> Duración: 16 segundos
# Start Time: 10833 - End Time: 10845 -> Duración: 12 segundos
# Start Time: 506 - End Time: 519 -> Duración: 13 segundos
# Start Time: 7799 - End Time: 7811 -> Duración: 12 segundos
# Start Time: 9387 - End Time: 9403 -> Duración: 16 segundos
# Número de seizures en el archivo /mnt/DGX0Raid/databases/CHB_data/txt_Files/chb06-summary.txt : 10
#
# Procesando archivo: /mnt/DGX0Raid/databases/CHB_data/txt_Files/chb05-summary.txt
# Start Time: 417 - End Time: 532 -> Duración: 115 segundos
# Start Time: 1086 - End Time: 1196 -> Duración: 110 segundos
# Start Time: 2317 - End Time: 2413 -> Duración: 96 segundos
# Start Time: 2451 - End Time: 2571 -> Duración: 120 segundos
# Start Time: 2348 - End Time: 2465 -> Duración: 117 segundos
# Número de seizures en el archivo /mnt/DGX0Raid/databases/CHB_data/txt_Files/chb05-summary.txt : 5
#
# Procesando archivo: /mnt/DGX0Raid/databases/CHB_data/txt_Files/chb16-summary.txt
# Start Time: 2290 - End Time: 2299 -> Duración: 9 segundos
# Start Time: 1120 - End Time: 1129 -> Duración: 9 segundos
# Start Time: 1854 - End Time: 1868 -> Duración: 14 segundos
# Start Time: 1214 - End Time: 1220 -> Duración: 6 segundos
# Start Time: 227 - End Time: 236 -> Duración: 9 segundos
# Start Time: 1694 - End Time: 1700 -> Duración: 6 segundos
# Start Time: 2162 - End Time: 2170 -> Duración: 8 segundos
# Start Time: 3290 - End Time: 3298 -> Duración: 8 segundos
# Start Time: 627 - End Time: 635 -> Duración: 8 segundos
# Start Time: 1909 - End Time: 1916 -> Duración: 7 segundos
# Número de seizures en el archivo /mnt/DGX0Raid/databases/CHB_data/txt_Files/chb16-summary.txt : 10
#
# Procesando archivo: /mnt/DGX0Raid/databases/CHB_data/txt_Files/chb24-summary.txt
# Start Time: 480 - End Time: 505 -> Duración: 25 segundos
# Start Time: 2451 - End Time: 2476 -> Duración: 25 segundos
# Start Time: 231 - End Time: 260 -> Duración: 29 segundos
# Start Time: 2883 - End Time: 2908 -> Duración: 25 segundos
# Start Time: 1088 - End Time: 1120 -> Duración: 32 segundos
# Start Time: 1411 - End Time: 1438 -> Duración: 27 segundos
# Start Time: 1745 - End Time: 1764 -> Duración: 19 segundos
# Start Time: 1229 - End Time: 1253 -> Duración: 24 segundos
# Start Time: 38 - End Time: 60 -> Duración: 22 segundos
# Start Time: 1745 - End Time: 1764 -> Duración: 19 segundos
# Start Time: 3527 - End Time: 3597 -> Duración: 70 segundos
# Start Time: 3288 - End Time: 3304 -> Duración: 16 segundos
# Start Time: 1939 - End Time: 1966 -> Duración: 27 segundos
# Start Time: 3552 - End Time: 3569 -> Duración: 17 segundos
# Start Time: 3515 - End Time: 3581 -> Duración: 66 segundos
# Start Time: 2804 - End Time: 2872 -> Duración: 68 segundos
# Número de seizures en el archivo /mnt/DGX0Raid/databases/CHB_data/txt_Files/chb24-summary.txt : 16
#
# Total de archivos procesados: 24
# Número total de duraciones encontradas: 198
#
# La mayor duración de un seizure episode es: 752 segundos

# %% [markdown]
# # Diccionario con el nombre del archivo edf y el inicio y fin de los episodios

# %%
import glob
import re

def extraer_episodios_desde_txt(ruta_archivo):
    """
    Lee un archivo de texto que contiene bloques con:
      File Name: chb01_01.edf
      File Start Time: ...
      File End Time: ...
      Number of Seizures in File: ...
      Seizure Start Time: ...
      Seizure End Time: ...
    y devuelve un diccionario donde cada clave es el nombre de archivo EDF (p.ej. 'chb01_01.edf'),
    y el valor es una lista de episodios con 'start' y 'end'.
    """
    dict_episodios = {}
    current_file_name = None  # Para ir guardando el nombre EDF actual

    with open(ruta_archivo, "r") as f:
        lineas = f.readlines()

        for i, linea in enumerate(lineas):
            # 1) Detectar si la línea contiene "File Name:"
            if "File Name:" in linea:
                # Extraer el nombre EDF, por ejemplo 'chb01_01.edf'
                match_file = re.search(r"File Name:\s*(\S+)", linea)
                if match_file:
                    current_file_name = match_file.group(1)
                    # Crear entrada vacía en el diccionario si no existe
                    if current_file_name not in dict_episodios:
                        dict_episodios[current_file_name] = []

            # 2) Detectar un Seizure Start Time y Seizure End Time
            if "Start Time:" in linea and "Seizure" in linea:
                start_match = re.search(r"Start Time:\s*(\d+)", linea)
                # Revisar la siguiente línea para el "Seizure End Time:"
                if start_match and (i + 1) < len(lineas) and "End Time:" in lineas[i+1] and "Seizure" in lineas[i+1]:
                    end_match = re.search(r"End Time:\s*(\d+)", lineas[i+1])
                    if end_match and current_file_name:
                        start_time = int(start_match.group(1))
                        end_time = int(end_match.group(1))
                        # Añadir este episodio al nombre de archivo EDF actual
                        dict_episodios[current_file_name].append({
                            "start": start_time,
                            "end": end_time
                        })

    return dict_episodios

def extraer_episodios_varios_txt(patron_archivos):
    """
    Recorre todos los archivos .txt que cumplan con el patrón (por ejemplo, "/ruta/*.txt"),
    y retorna un diccionario global donde cada clave es el nombre EDF (ej: 'chb01_01.edf')
    y su valor es la lista de episodios con 'start' y 'end' combinados.
    """
    dict_global = {}

    # Buscar todos los archivos que coinciden con el patrón
    lista_txt = glob.glob(patron_archivos)

    for ruta_txt in lista_txt:
        # Procesar el archivo .txt y obtener un diccionario parcial
        dict_parcial = extraer_episodios_desde_txt(ruta_txt)

        # Combinar con el diccionario global
        for edf_name, episodios in dict_parcial.items():
            if edf_name not in dict_global:
                dict_global[edf_name] = episodios
            else:
                # Si ya existe esa clave, concatenamos los nuevos episodios
                dict_global[edf_name].extend(episodios)

    return dict_global

if __name__ == "__main__":
    patron = "/mnt/DGX0Raid/databases/CHB_data/txt_Files/*.txt"
    dict_episodios = extraer_episodios_varios_txt(patron)

    # Calcular el número total de archivos procesados
    lista_txt = glob.glob(patron)
    total_archivos = len(lista_txt)

    # Calcular el número total de episodios encontrados
    total_episodios = sum(len(episodios) for episodios in dict_episodios.values())

    print(f"Total de archivos procesados: {total_archivos}")
    print(f"Número total de episodios encontrados: {total_episodios}")

    # Imprimir resultados por archivo EDF
    for edf_name, episodios in dict_episodios.items():
        print(f"\nEDF Name: {edf_name}")
        if episodios:
            for i, epi in enumerate(episodios, 1):
                print(f"  Episodio {i}: Start = {epi['start']}, End = {epi['end']}")
        else:
            print("  No se encontraron episodios para este archivo EDF.")
# Out:
# Total de archivos procesados: 24
# Número total de episodios encontrados: 198
#
# EDF Name: chb14_01.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb14_02.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb14_03.edf
#   Episodio 1: Start = 1986, End = 2000
#
# EDF Name: chb14_04.edf
#   Episodio 1: Start = 1372, End = 1392
#   Episodio 2: Start = 2817, End = 2839
#
# EDF Name: chb14_06.edf
#   Episodio 1: Start = 1911, End = 1925
#
# EDF Name: chb14_07.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb14_11.edf
#   Episodio 1: Start = 1838, End = 1879
#
# EDF Name: chb14_12.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb14_13.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb14_14.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb14_16.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb14_17.edf
#   Episodio 1: Start = 3239, End = 3259
#
# EDF Name: chb14_18.edf
#   Episodio 1: Start = 1039, End = 1061
#
# EDF Name: chb14_19.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb14_20.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb14_22.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb14_24.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb14_25.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb14_26.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb14_27.edf
#   Episodio 1: Start = 2833, End = 2849
#
# EDF Name: chb14_29.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb14_30.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb14_32.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb14_37.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb14_39.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb14_42.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb09_01.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb09_02.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb09_03.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb09_04.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb09_05.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb09_06.edf
#   Episodio 1: Start = 12231, End = 12295
#
# EDF Name: chb09_07.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb09_08.edf
#   Episodio 1: Start = 2951, End = 3030
#   Episodio 2: Start = 9196, End = 9267
#
# EDF Name: chb09_09.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb09_10.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb09_11.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb09_12.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb09_13.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb09_14.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb09_15.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb09_16.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb09_17.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb09_18.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb09_19.edf
#   Episodio 1: Start = 5299, End = 5361
#
# EDF Name: chb11_01.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb11_02.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb11_03.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb11_04.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb11_05.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb11_06.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb11_07.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb11_08.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb11_09.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb11_10.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb11_11.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb11_12.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb11_13.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb11_14.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb11_15.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb11_16.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb11_17.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb11_18.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb11_19.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb11_24.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb11_25.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb11_26.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb11_27.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb11_53.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb11_54.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb11_55.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb11_56.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb11_58.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb11_60.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb11_61.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb11_62.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb11_63.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb11_82.edf
#   Episodio 1: Start = 298, End = 320
#
# EDF Name: chb11_92.edf
#   Episodio 1: Start = 2695, End = 2727
#
# EDF Name: chb11_99.edf
#   Episodio 1: Start = 1454, End = 2206
#
# EDF Name: chb02_01.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb02_02.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb02_03.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb02_04.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb02_05.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb02_06.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb02_07.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb02_08.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb02_09.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb02_10.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb02_11.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb02_12.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb02_13.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb02_14.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb02_15.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb02_16.edf
#   Episodio 1: Start = 130, End = 212
#
# EDF Name: chb02_16+.edf
#   Episodio 1: Start = 2972, End = 3053
#
# EDF Name: chb02_17.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb02_18.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb02_19.edf
#   Episodio 1: Start = 3369, End = 3378
#
# EDF Name: chb02_20.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb02_21.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb02_22.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb02_23.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb02_24.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb02_25.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb02_26.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb02_27.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb02_28.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb02_29.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb02_30.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb02_31.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb02_32.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb02_33.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb02_34.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb02_35.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb07_01.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb07_02.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb07_03.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb07_04.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb07_05.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb07_06.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb07_07.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb07_08.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb07_09.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb07_10.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb07_11.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb07_12.edf
#   Episodio 1: Start = 4920, End = 5006
#
# EDF Name: chb07_13.edf
#   Episodio 1: Start = 3285, End = 3381
#
# EDF Name: chb07_14.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb07_15.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb07_16.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb07_17.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb07_18.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb07_19.edf
#   Episodio 1: Start = 13688, End = 13831
#
# EDF Name: chb13_02.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb13_03.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb13_04.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb13_05.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb13_06.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb13_07.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb13_08.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb13_09.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb13_10.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb13_11.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb13_12.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb13_13.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb13_14.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb13_15.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb13_16.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb13_18.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb13_19.edf
#   Episodio 1: Start = 2077, End = 2121
#
# EDF Name: chb13_21.edf
#   Episodio 1: Start = 934, End = 1004
#
# EDF Name: chb13_22.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb13_24.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb13_30.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb13_36.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb13_37.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb13_38.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb13_39.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb13_40.edf
#   Episodio 1: Start = 142, End = 173
#   Episodio 2: Start = 530, End = 594
#
# EDF Name: chb13_47.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb13_55.edf
#   Episodio 1: Start = 458, End = 478
#   Episodio 2: Start = 2436, End = 2454
#
# EDF Name: chb13_56.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb13_58.edf
#   Episodio 1: Start = 2474, End = 2491
#
# EDF Name: chb13_59.edf
#   Episodio 1: Start = 3339, End = 3401
#
# EDF Name: chb13_60.edf
#   Episodio 1: Start = 638, End = 660
#
# EDF Name: chb13_62.edf
#   Episodio 1: Start = 851, End = 916
#   Episodio 2: Start = 1626, End = 1691
#   Episodio 3: Start = 2664, End = 2721
#
# EDF Name: chb21_01.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb21_02.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb21_03.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb21_04.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb21_05.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb21_06.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb21_07.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb21_08.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb21_09.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb21_10.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb21_11.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb21_12.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb21_13.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb21_14.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb21_15.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb21_16.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb21_17.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb21_18.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb21_19.edf
#   Episodio 1: Start = 1288, End = 1344
#
# EDF Name: chb21_20.edf
#   Episodio 1: Start = 2627, End = 2677
#
# EDF Name: chb21_21.edf
#   Episodio 1: Start = 2003, End = 2084
#
# EDF Name: chb21_22.edf
#   Episodio 1: Start = 2553, End = 2565
#
# EDF Name: chb21_23.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb21_24.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb21_25.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb21_26.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb21_27.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb21_28.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb21_29.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb21_30.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb21_31.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb21_32.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb21_33.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb20_01.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb20_02.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb20_03.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb20_04.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb20_05.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb20_06.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb20_07.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb20_08.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb20_11.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb20_12.edf
#   Episodio 1: Start = 94, End = 123
#
# EDF Name: chb20_13.edf
#   Episodio 1: Start = 1440, End = 1470
#   Episodio 2: Start = 2498, End = 2537
#
# EDF Name: chb20_14.edf
#   Episodio 1: Start = 1971, End = 2009
#
# EDF Name: chb20_15.edf
#   Episodio 1: Start = 390, End = 425
#   Episodio 2: Start = 1689, End = 1738
#
# EDF Name: chb20_16.edf
#   Episodio 1: Start = 2226, End = 2261
#
# EDF Name: chb20_17.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb20_21.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb20_22.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb20_23.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb20_25.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb20_26.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb20_27.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb20_28.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb20_29.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb20_30.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb20_31.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb20_34.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb20_59.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb20_60.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb20_68.edf
#   Episodio 1: Start = 1393, End = 1432
#
# EDF Name: chb10_01.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb10_02.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb10_03.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb10_04.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb10_05.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb10_06.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb10_07.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb10_08.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb10_12.edf
#   Episodio 1: Start = 6313, End = 6348
#
# EDF Name: chb10_13.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb10_14.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb10_15.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb10_16.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb10_17.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb10_18.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb10_19.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb10_20.edf
#   Episodio 1: Start = 6888, End = 6958
#
# EDF Name: chb10_21.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb10_22.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb10_27.edf
#   Episodio 1: Start = 2382, End = 2447
#
# EDF Name: chb10_28.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb10_30.edf
#   Episodio 1: Start = 3021, End = 3079
#
# EDF Name: chb10_31.edf
#   Episodio 1: Start = 3801, End = 3877
#
# EDF Name: chb10_38.edf
#   Episodio 1: Start = 4618, End = 4707
#
# EDF Name: chb10_89.edf
#   Episodio 1: Start = 1383, End = 1437
#
# EDF Name: chb01_01.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb01_02.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb01_03.edf
#   Episodio 1: Start = 2996, End = 3036
#
# EDF Name: chb01_04.edf
#   Episodio 1: Start = 1467, End = 1494
#
# EDF Name: chb01_05.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb01_06.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb01_07.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb01_08.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb01_09.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb01_10.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb01_11.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb01_12.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb01_13.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb01_14.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb01_15.edf
#   Episodio 1: Start = 1732, End = 1772
#
# EDF Name: chb01_16.edf
#   Episodio 1: Start = 1015, End = 1066
#
# EDF Name: chb01_17.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb01_18.edf
#   Episodio 1: Start = 1720, End = 1810
#
# EDF Name: chb01_19.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb01_20.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb01_21.edf
#   Episodio 1: Start = 327, End = 420
#
# EDF Name: chb01_22.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb01_23.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb01_24.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb01_25.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb01_26.edf
#   Episodio 1: Start = 1862, End = 1963
#
# EDF Name: chb01_27.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb01_29.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb01_30.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb01_31.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb01_32.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb01_33.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb01_34.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb01_36.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb01_37.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb01_38.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb01_39.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb01_40.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb01_41.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb01_42.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb01_43.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb01_46.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb22_01.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb22_02.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb22_03.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb22_04.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb22_05.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb22_06.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb22_07.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb22_08.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb22_09.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb22_10.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb22_11.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb22_15.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb22_16.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb22_17.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb22_18.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb22_19.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb22_20.edf
#   Episodio 1: Start = 3367, End = 3425
#
# EDF Name: chb22_21.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb22_22.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb22_23.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb22_24.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb22_25.edf
#   Episodio 1: Start = 3139, End = 3213
#
# EDF Name: chb22_26.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb22_27.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb22_28.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb22_29.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb22_30.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb22_38.edf
#   Episodio 1: Start = 1263, End = 1335
#
# EDF Name: chb22_51.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb22_54.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb22_77.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb23_06.edf
#   Episodio 1: Start = 3962, End = 4075
#
# EDF Name: chb23_07.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb23_08.edf
#   Episodio 1: Start = 325, End = 345
#   Episodio 2: Start = 5104, End = 5151
#
# EDF Name: chb23_09.edf
#   Episodio 1: Start = 2589, End = 2660
#   Episodio 2: Start = 6885, End = 6947
#   Episodio 3: Start = 8505, End = 8532
#   Episodio 4: Start = 9580, End = 9664
#
# EDF Name: chb23_10.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb23_16.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb23_17.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb23_19.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb23_20.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb18_01.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb18_02.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb18_03.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb18_04.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb18_05.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb18_06.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb18_07.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb18_08.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb18_09.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb18_10.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb18_11.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb18_12.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb18_13.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb18_14.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb18_15.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb18_16.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb18_17.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb18_18.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb18_19.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb18_20.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb18_21.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb18_22.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb18_23.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb18_24.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb18_25.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb18_26.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb18_27.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb18_28.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb18_29.edf
#   Episodio 1: Start = 3477, End = 3527
#
# EDF Name: chb18_30.edf
#   Episodio 1: Start = 541, End = 571
#
# EDF Name: chb18_31.edf
#   Episodio 1: Start = 2087, End = 2155
#
# EDF Name: chb18_32.edf
#   Episodio 1: Start = 1908, End = 1963
#
# EDF Name: chb18_33.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb18_34.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb18_35.edf
#   Episodio 1: Start = 2196, End = 2264
#
# EDF Name: chb18_36.edf
#   Episodio 1: Start = 463, End = 509
#
# EDF Name: chb17a_03.edf
#   Episodio 1: Start = 2282, End = 2372
#
# EDF Name: chb17a_04.edf
#   Episodio 1: Start = 3025, End = 3140
#
# EDF Name: chb17a_05.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb17a_06.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb17a_08.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb17b_57.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb17b_58.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb17b_59.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb17b_60.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb17b_63.edf
#   Episodio 1: Start = 3136, End = 3224
#
# EDF Name: chb17b_67.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb17b_68.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb17b_69.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb17c_02.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb17c_03.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb17c_04.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb17c_05.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb17c_06.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb17c_07.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb17c_08.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb17c_13.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb12_06.edf
#   Episodio 1: Start = 1665, End = 1726
#   Episodio 2: Start = 3415, End = 3447
#
# EDF Name: chb12_08.edf
#   Episodio 1: Start = 1426, End = 1439
#   Episodio 2: Start = 1591, End = 1614
#   Episodio 3: Start = 1957, End = 1977
#   Episodio 4: Start = 2798, End = 2824
#
# EDF Name: chb12_09.edf
#   Episodio 1: Start = 3082, End = 3114
#   Episodio 2: Start = 3503, End = 3535
#
# EDF Name: chb12_10.edf
#   Episodio 1: Start = 593, End = 625
#   Episodio 2: Start = 811, End = 856
#
# EDF Name: chb12_11.edf
#   Episodio 1: Start = 1085, End = 1122
#
# EDF Name: chb12_19.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb12_20.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb12_21.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb12_23.edf
#   Episodio 1: Start = 253, End = 333
#   Episodio 2: Start = 425, End = 522
#   Episodio 3: Start = 630, End = 670
#
# EDF Name: chb12_24.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb12_27.edf
#   Episodio 1: Start = 916, End = 951
#   Episodio 2: Start = 1097, End = 1124
#   Episodio 3: Start = 1728, End = 1753
#   Episodio 4: Start = 1921, End = 1963
#   Episodio 5: Start = 2388, End = 2440
#   Episodio 6: Start = 2621, End = 2669
#
# EDF Name: chb12_28.edf
#   Episodio 1: Start = 181, End = 215
#
# EDF Name: chb12_29.edf
#   Episodio 1: Start = 107, End = 146
#   Episodio 2: Start = 554, End = 592
#   Episodio 3: Start = 1163, End = 1199
#   Episodio 4: Start = 1401, End = 1447
#   Episodio 5: Start = 1884, End = 1921
#   Episodio 6: Start = 3557, End = 3584
#
# EDF Name: chb12_32.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb12_33.edf
#   Episodio 1: Start = 2185, End = 2206
#   Episodio 2: Start = 2427, End = 2450
#
# EDF Name: chb12_34.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb12_35.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb12_36.edf
#   Episodio 1: Start = 653, End = 680
#
# EDF Name: chb12_37.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb12_38.edf
#   Episodio 1: Start = 1548, End = 1573
#   Episodio 2: Start = 2798, End = 2821
#   Episodio 3: Start = 2966, End = 3009
#   Episodio 4: Start = 3146, End = 3201
#   Episodio 5: Start = 3364, End = 3410
#
# EDF Name: chb12_39.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb12_40.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb12_41.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb12_42.edf
#   Episodio 1: Start = 699, End = 750
#   Episodio 2: Start = 945, End = 973
#   Episodio 3: Start = 1170, End = 1199
#   Episodio 4: Start = 1676, End = 1701
#   Episodio 5: Start = 2213, End = 2236
#
# EDF Name: chb08_02.edf
#   Episodio 1: Start = 2670, End = 2841
#
# EDF Name: chb08_03.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb08_04.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb08_05.edf
#   Episodio 1: Start = 2856, End = 3046
#
# EDF Name: chb08_10.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb08_11.edf
#   Episodio 1: Start = 2988, End = 3122
#
# EDF Name: chb08_12.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb08_13.edf
#   Episodio 1: Start = 2417, End = 2577
#
# EDF Name: chb08_14.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb08_15.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb08_16.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb08_17.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb08_18.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb08_19.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb08_20.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb08_21.edf
#   Episodio 1: Start = 2083, End = 2347
#
# EDF Name: chb08_22.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb08_23.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb08_24.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb08_29.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb03_01.edf
#   Episodio 1: Start = 362, End = 414
#
# EDF Name: chb03_02.edf
#   Episodio 1: Start = 731, End = 796
#
# EDF Name: chb03_03.edf
#   Episodio 1: Start = 432, End = 501
#
# EDF Name: chb03_04.edf
#   Episodio 1: Start = 2162, End = 2214
#
# EDF Name: chb03_05.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb03_06.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb03_07.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb03_08.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb03_09.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb03_10.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb03_11.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb03_12.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb03_13.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb03_14.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb03_15.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb03_16.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb03_17.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb03_18.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb03_19.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb03_20.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb03_21.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb03_22.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb03_23.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb03_24.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb03_25.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb03_26.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb03_27.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb03_28.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb03_29.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb03_30.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb03_31.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb03_32.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb03_33.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb03_34.edf
#   Episodio 1: Start = 1982, End = 2029
#
# EDF Name: chb03_35.edf
#   Episodio 1: Start = 2592, End = 2656
#
# EDF Name: chb03_36.edf
#   Episodio 1: Start = 1725, End = 1778
#
# EDF Name: chb03_37.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb03_38.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb15_01.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb15_02.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb15_03.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb15_04.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb15_05.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb15_06.edf
#   Episodio 1: Start = 272, End = 397
#
# EDF Name: chb15_07.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb15_08.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb15_09.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb15_10.edf
#   Episodio 1: Start = 1082, End = 1113
#
# EDF Name: chb15_11.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb15_12.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb15_13.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb15_14.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb15_15.edf
#   Episodio 1: Start = 1591, End = 1748
#
# EDF Name: chb15_16.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb15_17.edf
#   Episodio 1: Start = 1925, End = 1960
#
# EDF Name: chb15_19.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb15_20.edf
#   Episodio 1: Start = 607, End = 662
#
# EDF Name: chb15_22.edf
#   Episodio 1: Start = 760, End = 965
#
# EDF Name: chb15_26.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb15_28.edf
#   Episodio 1: Start = 876, End = 1066
#
# EDF Name: chb15_29.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb15_30.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb15_31.edf
#   Episodio 1: Start = 1751, End = 1871
#
# EDF Name: chb15_32.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb15_33.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb15_35.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb15_37.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb15_40.edf
#   Episodio 1: Start = 834, End = 894
#   Episodio 2: Start = 2378, End = 2497
#   Episodio 3: Start = 3362, End = 3425
#
# EDF Name: chb15_45.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb15_46.edf
#   Episodio 1: Start = 3322, End = 3429
#
# EDF Name: chb15_49.edf
#   Episodio 1: Start = 1108, End = 1248
#
# EDF Name: chb15_50.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb15_51.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb15_52.edf
#   Episodio 1: Start = 778, End = 849
#
# EDF Name: chb15_54.edf
#   Episodio 1: Start = 263, End = 318
#   Episodio 2: Start = 843, End = 1020
#   Episodio 3: Start = 1524, End = 1595
#   Episodio 4: Start = 2179, End = 2250
#   Episodio 5: Start = 3428, End = 3460
#
# EDF Name: chb15_61.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb15_62.edf
#   Episodio 1: Start = 751, End = 859
#
# EDF Name: chb15_63.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb19_01.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb19_02.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb19_03.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb19_04.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb19_05.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb19_06.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb19_07.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb19_08.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb19_09.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb19_10.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb19_11.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb19_12.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb19_13.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb19_14.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb19_15.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb19_16.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb19_17.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb19_18.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb19_19.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb19_20.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb19_21.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb19_22.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb19_23.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb19_24.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb19_25.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb19_26.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb19_27.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb19_28.edf
#   Episodio 1: Start = 299, End = 377
#
# EDF Name: chb19_29.edf
#   Episodio 1: Start = 2964, End = 3041
#
# EDF Name: chb19_30.edf
#   Episodio 1: Start = 3159, End = 3240
#
# EDF Name: chb04_01.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb04_02.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb04_03.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb04_04.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb04_05.edf
#   Episodio 1: Start = 7804, End = 7853
#
# EDF Name: chb04_06.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb04_07.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb04_08.edf
#   Episodio 1: Start = 6446, End = 6557
#
# EDF Name: chb04_09.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb04_10.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb04_11.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb04_12.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb04_13.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb04_14.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb04_15.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb04_16.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb04_17.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb04_18.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb04_19.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb04_21.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb04_22.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb04_23.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb04_24.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb04_25.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb04_26.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb04_27.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb04_28.edf
#   Episodio 1: Start = 1679, End = 1781
#   Episodio 2: Start = 3782, End = 3898
#
# EDF Name: chb04_29.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb04_30.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb04_31.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb04_32.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb04_33.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb04_34.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb04_35.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb04_36.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb04_37.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb04_38.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb04_39.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb04_40.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb04_41.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb04_42.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb04_43.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb06_01.edf
#   Episodio 1: Start = 1724, End = 1738
#   Episodio 2: Start = 7461, End = 7476
#   Episodio 3: Start = 13525, End = 13540
#
# EDF Name: chb06_02.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb06_03.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb06_04.edf
#   Episodio 1: Start = 327, End = 347
#   Episodio 2: Start = 6211, End = 6231
#
# EDF Name: chb06_05.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb06_06.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb06_07.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb06_08.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb06_09.edf
#   Episodio 1: Start = 12500, End = 12516
#
# EDF Name: chb06_10.edf
#   Episodio 1: Start = 10833, End = 10845
#
# EDF Name: chb06_12.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb06_13.edf
#   Episodio 1: Start = 506, End = 519
#
# EDF Name: chb06_14.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb06_15.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb06_16.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb06_17.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb06_18.edf
#   Episodio 1: Start = 7799, End = 7811
#
# EDF Name: chb06_24.edf
#   Episodio 1: Start = 9387, End = 9403
#
# EDF Name: chb05_01.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb05_02.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb05_03.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb05_04.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb05_05.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb05_06.edf
#   Episodio 1: Start = 417, End = 532
#
# EDF Name: chb05_07.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb05_08.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb05_09.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb05_10.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb05_11.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb05_12.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb05_13.edf
#   Episodio 1: Start = 1086, End = 1196
#
# EDF Name: chb05_14.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb05_15.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb05_16.edf
#   Episodio 1: Start = 2317, End = 2413
#
# EDF Name: chb05_17.edf
#   Episodio 1: Start = 2451, End = 2571
#
# EDF Name: chb05_18.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb05_19.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb05_20.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb05_21.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb05_22.edf
#   Episodio 1: Start = 2348, End = 2465
#
# EDF Name: chb05_23.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb05_24.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb05_25.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb05_26.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb05_27.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb05_28.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb05_29.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb05_30.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb05_31.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb05_32.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb05_33.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb05_34.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb05_35.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb05_36.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb05_37.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb05_38.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb05_39.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb16_01.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb16_02.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb16_03.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb16_04.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb16_05.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb16_06.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb16_07.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb16_08.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb16_09.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb16_10.edf
#   Episodio 1: Start = 2290, End = 2299
#
# EDF Name: chb16_11.edf
#   Episodio 1: Start = 1120, End = 1129
#
# EDF Name: chb16_12.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb16_13.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb16_14.edf
#   Episodio 1: Start = 1854, End = 1868
#
# EDF Name: chb16_15.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb16_16.edf
#   Episodio 1: Start = 1214, End = 1220
#
# EDF Name: chb16_17.edf
#   Episodio 1: Start = 227, End = 236
#   Episodio 2: Start = 1694, End = 1700
#   Episodio 3: Start = 2162, End = 2170
#   Episodio 4: Start = 3290, End = 3298
#
# EDF Name: chb16_18.edf
#   Episodio 1: Start = 627, End = 635
#   Episodio 2: Start = 1909, End = 1916
#
# EDF Name: chb16_19.edf
#   No se encontraron episodios para este archivo EDF.
#
# EDF Name: chb24_01.edf
#   Episodio 1: Start = 480, End = 505
#   Episodio 2: Start = 2451, End = 2476
#
# EDF Name: chb24_03.edf
#   Episodio 1: Start = 231, End = 260
#   Episodio 2: Start = 2883, End = 2908
#
# EDF Name: chb24_04.edf
#   Episodio 1: Start = 1088, End = 1120
#   Episodio 2: Start = 1411, End = 1438
#   Episodio 3: Start = 1745, End = 1764
#
# EDF Name: chb24_06.edf
#   Episodio 1: Start = 1229, End = 1253
#
# EDF Name: chb24_07.edf
#   Episodio 1: Start = 38, End = 60
#
# EDF Name: chb24_09.edf
#   Episodio 1: Start = 1745, End = 1764
#
# EDF Name: chb24_11.edf
#   Episodio 1: Start = 3527, End = 3597
#
# EDF Name: chb24_13.edf
#   Episodio 1: Start = 3288, End = 3304
#
# EDF Name: chb24_14.edf
#   Episodio 1: Start = 1939, End = 1966
#
# EDF Name: chb24_15.edf
#   Episodio 1: Start = 3552, End = 3569
#
# EDF Name: chb24_17.edf
#   Episodio 1: Start = 3515, End = 3581
#
# EDF Name: chb24_21.edf
#   Episodio 1: Start = 2804, End = 2872

# %%
dict_episodios

# %% [markdown]
# # Creación de listas normal y epiléptica con los nombres de los archivos

# %%
import glob
import re

def clasificar_archivos_desde_txt(ruta_archivo):
    """
    Lee un archivo de texto que contiene información en líneas como:
      File Name: chb01_01.edf
      Number of Seizures in File: 0
    y clasifica el archivo como normal o con epilepsia según el número de seizures.

    Retorna dos listas:
      - normal_files (contiene los nombres de archivo EDF con 0 seizures)
      - epileptic_files (contiene los nombres de archivo EDF con >=1 seizures)
    """
    normal_files = []
    epileptic_files = []

    current_file_name = None

    with open(ruta_archivo, "r") as f:
        lineas = f.readlines()

        for linea in lineas:
            # Detectar el nombre del archivo EDF
            if "File Name:" in linea:
                match_file = re.search(r"File Name:\s*(\S+)", linea)
                if match_file:
                    current_file_name = match_file.group(1)

            # Detectar el número de seizures en el archivo
            if "Number of Seizures in File:" in linea:
                match_seizures = re.search(r"Number of Seizures in File:\s*(\d+)", linea)
                if match_seizures and current_file_name:
                    num_seizures = int(match_seizures.group(1))

                    if num_seizures == 0:
                        normal_files.append(current_file_name)
                    else:
                        epileptic_files.append(current_file_name)

                    # Reseteamos el current_file_name para el siguiente bloque
                    current_file_name = None

    return normal_files, epileptic_files

def clasificar_archivos_varios_txt(patron_archivos):
    """
    Recorre todos los archivos .txt que cumplan con el patrón y
    genera dos listas globales:
      - normal_files (archivos EDF con 0 seizures)
      - epileptic_files (archivos EDF con >=1 seizures)
    """
    normal_files = set()
    epileptic_files = set()

    lista_txt = glob.glob(patron_archivos)
    for ruta_txt in lista_txt:
        nf, ef = clasificar_archivos_desde_txt(ruta_txt)
        normal_files.update(nf)
        epileptic_files.update(ef)

    return list(normal_files), list(epileptic_files)

def ordenar_por_numero_chb(lista_archivos):
    """
    Ordena una lista de nombres de archivos según el número que aparece
    justo después de "chb". Por ejemplo, 'chb01_01.edf' se ordenará antes de 'chb10_03.edf'.
    """
    # Usamos re.IGNORECASE por si acaso el prefijo está en mayúsculas o minúsculas.
    return sorted(lista_archivos, key=lambda x: int(re.search(r'chb(\d+)', x, re.IGNORECASE).group(1)))

if __name__ == "__main__":
    patron = "/mnt/DGX0Raid/databases/CHB_data/txt_Files/*.txt"
    normal_list, epileptic_list = clasificar_archivos_varios_txt(patron)

    # Ordenar las listas según el número que sigue a "chb"
    normal_list_ordenada = ordenar_por_numero_chb(normal_list)
    epileptic_list_ordenada = ordenar_por_numero_chb(epileptic_list)

    print("Archivos normales (0 seizures) ordenados:")
    for f in normal_list_ordenada:
        print("  ", f)

    print("\nArchivos con epilepsia (>=1 seizures) ordenados:")
    for f in epileptic_list_ordenada:
        print("  ", f)

    # Si necesitas conocer el total de file names (únicos) en cada categoría:
    print("\nTotal de archivos normales:", len(normal_list_ordenada))
    print("Total de archivos con epilepsia:", len(epileptic_list_ordenada))
# Out:
# Archivos normales (0 seizures) ordenados:
#    chb01_33.edf
#    chb01_43.edf
#    chb01_19.edf
#    chb01_37.edf
#    chb01_31.edf
#    chb01_22.edf
#    chb01_06.edf
#    chb01_42.edf
#    chb01_20.edf
#    chb01_36.edf
#    chb01_46.edf
#    chb01_39.edf
#    chb01_09.edf
#    chb01_08.edf
#    chb01_13.edf
#    chb01_14.edf
#    chb01_11.edf
#    chb01_29.edf
#    chb01_17.edf
#    chb01_01.edf
#    chb01_34.edf
#    chb01_07.edf
#    chb01_02.edf
#    chb01_10.edf
#    chb01_32.edf
#    chb01_24.edf
#    chb01_23.edf
#    chb01_41.edf
#    chb01_38.edf
#    chb01_27.edf
#    chb01_12.edf
#    chb01_25.edf
#    chb01_30.edf
#    chb01_05.edf
#    chb01_40.edf
#    chb02_03.edf
#    chb02_11.edf
#    chb02_21.edf
#    chb02_27.edf
#    chb02_30.edf
#    chb02_04.edf
#    chb02_15.edf
#    chb02_07.edf
#    chb02_24.edf
#    chb02_18.edf
#    chb02_14.edf
#    chb02_28.edf
#    chb02_02.edf
#    chb02_20.edf
#    chb02_09.edf
#    chb02_22.edf
#    chb02_01.edf
#    chb02_34.edf
#    chb02_26.edf
#    chb02_23.edf
#    chb02_05.edf
#    chb02_06.edf
#    chb02_31.edf
#    chb02_13.edf
#    chb02_29.edf
#    chb02_10.edf
#    chb02_35.edf
#    chb02_32.edf
#    chb02_33.edf
#    chb02_25.edf
#    chb02_17.edf
#    chb02_12.edf
#    chb02_08.edf
#    chb03_29.edf
#    chb03_23.edf
#    chb03_11.edf
#    chb03_20.edf
#    chb03_38.edf
#    chb03_31.edf
#    chb03_22.edf
#    chb03_28.edf
#    chb03_05.edf
#    chb03_06.edf
#    chb03_18.edf
#    chb03_16.edf
#    chb03_37.edf
#    chb03_21.edf
#    chb03_24.edf
#    chb03_27.edf
#    chb03_26.edf
#    chb03_17.edf
#    chb03_07.edf
#    chb03_15.edf
#    chb03_14.edf
#    chb03_12.edf
#    chb03_30.edf
#    chb03_08.edf
#    chb03_25.edf
#    chb03_32.edf
#    chb03_19.edf
#    chb03_33.edf
#    chb03_13.edf
#    chb03_10.edf
#    chb03_09.edf
#    chb04_34.edf
#    chb04_09.edf
#    chb04_30.edf
#    chb04_43.edf
#    chb04_21.edf
#    chb04_38.edf
#    chb04_11.edf
#    chb04_01.edf
#    chb04_06.edf
#    chb04_02.edf
#    chb04_42.edf
#    chb04_29.edf
#    chb04_14.edf
#    chb04_16.edf
#    chb04_32.edf
#    chb04_10.edf
#    chb04_37.edf
#    chb04_40.edf
#    chb04_15.edf
#    chb04_18.edf
#    chb04_03.edf
#    chb04_24.edf
#    chb04_27.edf
#    chb04_33.edf
#    chb04_25.edf
#    chb04_36.edf
#    chb04_04.edf
#    chb04_23.edf
#    chb04_31.edf
#    chb04_26.edf
#    chb04_07.edf
#    chb04_19.edf
#    chb04_41.edf
#    chb04_12.edf
#    chb04_35.edf
#    chb04_17.edf
#    chb04_39.edf
#    chb04_22.edf
#    chb04_13.edf
#    chb05_21.edf
#    chb05_05.edf
#    chb05_27.edf
#    chb05_03.edf
#    chb05_38.edf
#    chb05_39.edf
#    chb05_30.edf
#    chb05_15.edf
#    chb05_07.edf
#    chb05_26.edf
#    chb05_36.edf
#    chb05_29.edf
#    chb05_14.edf
#    chb05_33.edf
#    chb05_28.edf
#    chb05_10.edf
#    chb05_18.edf
#    chb05_24.edf
#    chb05_04.edf
#    chb05_34.edf
#    chb05_32.edf
#    chb05_02.edf
#    chb05_09.edf
#    chb05_20.edf
#    chb05_35.edf
#    chb05_08.edf
#    chb05_31.edf
#    chb05_25.edf
#    chb05_12.edf
#    chb05_37.edf
#    chb05_01.edf
#    chb05_23.edf
#    chb05_11.edf
#    chb05_19.edf
#    chb06_17.edf
#    chb06_15.edf
#    chb06_05.edf
#    chb06_16.edf
#    chb06_12.edf
#    chb06_03.edf
#    chb06_14.edf
#    chb06_06.edf
#    chb06_02.edf
#    chb06_07.edf
#    chb06_08.edf
#    chb07_17.edf
#    chb07_14.edf
#    chb07_11.edf
#    chb07_01.edf
#    chb07_10.edf
#    chb07_18.edf
#    chb07_09.edf
#    chb07_06.edf
#    chb07_08.edf
#    chb07_03.edf
#    chb07_07.edf
#    chb07_05.edf
#    chb07_02.edf
#    chb07_16.edf
#    chb07_04.edf
#    chb07_15.edf
#    chb08_03.edf
#    chb08_15.edf
#    chb08_14.edf
#    chb08_20.edf
#    chb08_12.edf
#    chb08_24.edf
#    chb08_18.edf
#    chb08_16.edf
#    chb08_19.edf
#    chb08_04.edf
#    chb08_17.edf
#    chb08_29.edf
#    chb08_10.edf
#    chb08_23.edf
#    chb08_22.edf
#    chb09_17.edf
#    chb09_13.edf
#    chb09_10.edf
#    chb09_15.edf
#    chb09_09.edf
#    chb09_12.edf
#    chb09_05.edf
#    chb09_04.edf
#    chb09_01.edf
#    chb09_16.edf
#    chb09_07.edf
#    chb09_14.edf
#    chb09_18.edf
#    chb09_02.edf
#    chb09_11.edf
#    chb09_03.edf
#    chb10_28.edf
#    chb10_01.edf
#    chb10_14.edf
#    chb10_07.edf
#    chb10_03.edf
#    chb10_15.edf
#    chb10_22.edf
#    chb10_16.edf
#    chb10_02.edf
#    chb10_17.edf
#    chb10_08.edf
#    chb10_05.edf
#    chb10_19.edf
#    chb10_13.edf
#    chb10_18.edf
#    chb10_04.edf
#    chb10_21.edf
#    chb10_06.edf
#    chb11_18.edf
#    chb11_27.edf
#    chb11_25.edf
#    chb11_55.edf
#    chb11_60.edf
#    chb11_54.edf
#    chb11_26.edf
#    chb11_61.edf
#    chb11_24.edf
#    chb11_02.edf
#    chb11_10.edf
#    chb11_14.edf
#    chb11_13.edf
#    chb11_16.edf
#    chb11_08.edf
#    chb11_15.edf
#    chb11_09.edf
#    chb11_03.edf
#    chb11_63.edf
#    chb11_12.edf
#    chb11_58.edf
#    chb11_11.edf
#    chb11_17.edf
#    chb11_62.edf
#    chb11_56.edf
#    chb11_01.edf
#    chb11_06.edf
#    chb11_19.edf
#    chb11_05.edf
#    chb11_07.edf
#    chb11_53.edf
#    chb11_04.edf
#    chb12_39.edf
#    chb12_21.edf
#    chb12_20.edf
#    chb12_32.edf
#    chb12_37.edf
#    chb12_35.edf
#    chb12_24.edf
#    chb12_41.edf
#    chb12_34.edf
#    chb12_40.edf
#    chb12_19.edf
#    chb13_09.edf
#    chb13_16.edf
#    chb13_14.edf
#    chb13_38.edf
#    chb13_15.edf
#    chb13_24.edf
#    chb13_22.edf
#    chb13_13.edf
#    chb13_12.edf
#    chb13_56.edf
#    chb13_18.edf
#    chb13_37.edf
#    chb13_04.edf
#    chb13_47.edf
#    chb13_05.edf
#    chb13_07.edf
#    chb13_39.edf
#    chb13_36.edf
#    chb13_03.edf
#    chb13_11.edf
#    chb13_30.edf
#    chb13_10.edf
#    chb13_02.edf
#    chb13_06.edf
#    chb13_08.edf
#    chb14_22.edf
#    chb14_13.edf
#    chb14_20.edf
#    chb14_16.edf
#    chb14_30.edf
#    chb14_42.edf
#    chb14_07.edf
#    chb14_12.edf
#    chb14_24.edf
#    chb14_29.edf
#    chb14_01.edf
#    chb14_19.edf
#    chb14_14.edf
#    chb14_37.edf
#    chb14_39.edf
#    chb14_02.edf
#    chb14_32.edf
#    chb14_25.edf
#    chb14_26.edf
#    chb15_13.edf
#    chb15_32.edf
#    chb15_51.edf
#    chb15_35.edf
#    chb15_16.edf
#    chb15_29.edf
#    chb15_05.edf
#    chb15_14.edf
#    chb15_61.edf
#    chb15_07.edf
#    chb15_26.edf
#    chb15_50.edf
#    chb15_11.edf
#    chb15_04.edf
#    chb15_30.edf
#    chb15_45.edf
#    chb15_09.edf
#    chb15_08.edf
#    chb15_19.edf
#    chb15_03.edf
#    chb15_12.edf
#    chb15_37.edf
#    chb15_01.edf
#    chb15_33.edf
#    chb15_63.edf
#    chb15_02.edf
#    chb16_01.edf
#    chb16_07.edf
#    chb16_05.edf
#    chb16_13.edf
#    chb16_03.edf
#    chb16_12.edf
#    chb16_02.edf
#    chb16_15.edf
#    chb16_19.edf
#    chb16_08.edf
#    chb16_09.edf
#    chb16_06.edf
#    chb16_04.edf
#    chb17b_59.edf
#    chb17b_58.edf
#    chb17b_67.edf
#    chb17b_68.edf
#    chb17a_08.edf
#    chb17b_69.edf
#    chb17b_57.edf
#    chb17a_06.edf
#    chb17c_13.edf
#    chb17c_07.edf
#    chb17a_05.edf
#    chb17c_08.edf
#    chb17c_05.edf
#    chb17b_60.edf
#    chb17c_06.edf
#    chb17c_02.edf
#    chb17c_03.edf
#    chb17c_04.edf
#    chb18_25.edf
#    chb18_10.edf
#    chb18_11.edf
#    chb18_08.edf
#    chb18_05.edf
#    chb18_17.edf
#    chb18_07.edf
#    chb18_03.edf
#    chb18_14.edf
#    chb18_33.edf
#    chb18_34.edf
#    chb18_09.edf
#    chb18_20.edf
#    chb18_01.edf
#    chb18_21.edf
#    chb18_16.edf
#    chb18_12.edf
#    chb18_24.edf
#    chb18_23.edf
#    chb18_02.edf
#    chb18_22.edf
#    chb18_04.edf
#    chb18_13.edf
#    chb18_15.edf
#    chb18_19.edf
#    chb18_06.edf
#    chb18_28.edf
#    chb18_26.edf
#    chb18_27.edf
#    chb18_18.edf
#    chb19_22.edf
#    chb19_23.edf
#    chb19_18.edf
#    chb19_17.edf
#    chb19_26.edf
#    chb19_27.edf
#    chb19_01.edf
#    chb19_12.edf
#    chb19_06.edf
#    chb19_19.edf
#    chb19_08.edf
#    chb19_05.edf
#    chb19_15.edf
#    chb19_07.edf
#    chb19_14.edf
#    chb19_04.edf
#    chb19_16.edf
#    chb19_13.edf
#    chb19_02.edf
#    chb19_24.edf
#    chb19_11.edf
#    chb19_09.edf
#    chb19_21.edf
#    chb19_10.edf
#    chb19_03.edf
#    chb19_25.edf
#    chb19_20.edf
#    chb20_25.edf
#    chb20_06.edf
#    chb20_27.edf
#    chb20_08.edf
#    chb20_26.edf
#    chb20_60.edf
#    chb20_01.edf
#    chb20_17.edf
#    chb20_23.edf
#    chb20_28.edf
#    chb20_05.edf
#    chb20_30.edf
#    chb20_03.edf
#    chb20_59.edf
#    chb20_31.edf
#    chb20_21.edf
#    chb20_04.edf
#    chb20_02.edf
#    chb20_29.edf
#    chb20_07.edf
#    chb20_11.edf
#    chb20_34.edf
#    chb20_22.edf
#    chb21_16.edf
#    chb21_33.edf
#    chb21_29.edf
#    chb21_10.edf
#    chb21_12.edf
#    chb21_31.edf
#    chb21_17.edf
#    chb21_15.edf
#    chb21_13.edf
#    chb21_09.edf
#    chb21_14.edf
#    chb21_08.edf
#    chb21_18.edf
#    chb21_06.edf
#    chb21_26.edf
#    chb21_01.edf
#    chb21_30.edf
#    chb21_25.edf
#    chb21_32.edf
#    chb21_11.edf
#    chb21_23.edf
#    chb21_07.edf
#    chb21_27.edf
#    chb21_28.edf
#    chb21_03.edf
#    chb21_24.edf
#    chb21_04.edf
#    chb21_05.edf
#    chb21_02.edf
#    chb22_04.edf
#    chb22_26.edf
#    chb22_01.edf
#    chb22_08.edf
#    chb22_06.edf
#    chb22_17.edf
#    chb22_16.edf
#    chb22_23.edf
#    chb22_28.edf
#    chb22_30.edf
#    chb22_02.edf
#    chb22_07.edf
#    chb22_19.edf
#    chb22_15.edf
#    chb22_05.edf
#    chb22_18.edf
#    chb22_51.edf
#    chb22_03.edf
#    chb22_27.edf
#    chb22_22.edf
#    chb22_10.edf
#    chb22_54.edf
#    chb22_09.edf
#    chb22_11.edf
#    chb22_77.edf
#    chb22_21.edf
#    chb22_24.edf
#    chb22_29.edf
#    chb23_17.edf
#    chb23_10.edf
#    chb23_07.edf
#    chb23_16.edf
#    chb23_20.edf
#    chb23_19.edf
#
# Archivos con epilepsia (>=1 seizures) ordenados:
#    chb01_15.edf
#    chb01_03.edf
#    chb01_16.edf
#    chb01_18.edf
#    chb01_26.edf
#    chb01_04.edf
#    chb01_21.edf
#    chb02_19.edf
#    chb02_16+.edf
#    chb02_16.edf
#    chb03_03.edf
#    chb03_02.edf
#    chb03_34.edf
#    chb03_36.edf
#    chb03_01.edf
#    chb03_35.edf
#    chb03_04.edf
#    chb04_28.edf
#    chb04_05.edf
#    chb04_08.edf
#    chb05_22.edf
#    chb05_13.edf
#    chb05_06.edf
#    chb05_16.edf
#    chb05_17.edf
#    chb06_18.edf
#    chb06_01.edf
#    chb06_13.edf
#    chb06_10.edf
#    chb06_09.edf
#    chb06_04.edf
#    chb06_24.edf
#    chb07_19.edf
#    chb07_13.edf
#    chb07_12.edf
#    chb08_05.edf
#    chb08_02.edf
#    chb08_11.edf
#    chb08_21.edf
#    chb08_13.edf
#    chb09_19.edf
#    chb09_06.edf
#    chb09_08.edf
#    chb10_38.edf
#    chb10_27.edf
#    chb10_31.edf
#    chb10_12.edf
#    chb10_89.edf
#    chb10_20.edf
#    chb10_30.edf
#    chb11_99.edf
#    chb11_92.edf
#    chb11_82.edf
#    chb12_10.edf
#    chb12_33.edf
#    chb12_08.edf
#    chb12_28.edf
#    chb12_11.edf
#    chb12_27.edf
#    chb12_29.edf
#    chb12_23.edf
#    chb12_42.edf
#    chb12_06.edf
#    chb12_38.edf
#    chb12_09.edf
#    chb12_36.edf
#    chb13_55.edf
#    chb13_62.edf
#    chb13_40.edf
#    chb13_21.edf
#    chb13_60.edf
#    chb13_19.edf
#    chb13_59.edf
#    chb13_58.edf
#    chb14_11.edf
#    chb14_04.edf
#    chb14_17.edf
#    chb14_27.edf
#    chb14_03.edf
#    chb14_06.edf
#    chb14_18.edf
#    chb15_52.edf
#    chb15_40.edf
#    chb15_62.edf
#    chb15_28.edf
#    chb15_20.edf
#    chb15_10.edf
#    chb15_49.edf
#    chb15_17.edf
#    chb15_06.edf
#    chb15_22.edf
#    chb15_31.edf
#    chb15_54.edf
#    chb15_15.edf
#    chb15_46.edf
#    chb16_16.edf
#    chb16_14.edf
#    chb16_11.edf
#    chb16_17.edf
#    chb16_18.edf
#    chb16_10.edf
#    chb17a_03.edf
#    chb17a_04.edf
#    chb17b_63.edf
#    chb18_32.edf
#    chb18_29.edf
#    chb18_30.edf
#    chb18_31.edf
#    chb18_36.edf
#    chb18_35.edf
#    chb19_30.edf
#    chb19_28.edf
#    chb19_29.edf
#    chb20_12.edf
#    chb20_15.edf
#    chb20_14.edf
#    chb20_16.edf
#    chb20_68.edf
#    chb20_13.edf
#    chb21_19.edf
#    chb21_22.edf
#    chb21_21.edf
#    chb21_20.edf
#    chb22_38.edf
#    chb22_20.edf
#    chb22_25.edf
#    chb23_08.edf
#    chb23_06.edf
#    chb23_09.edf
#    chb24_17.edf
#    chb24_13.edf
#    chb24_03.edf
#    chb24_21.edf
#    chb24_14.edf
#    chb24_09.edf
#    chb24_11.edf
#    chb24_15.edf
#    chb24_01.edf
#    chb24_06.edf
#    chb24_07.edf
#    chb24_04.edf
#
# Total de archivos normales: 535
# Total de archivos con epilepsia: 141

# %% [markdown]
# # Muestreo de archivos edf normales y balanceo de clases

# %%
import random

# Ejemplo: Supongamos que estos son tus datos.
# La lista 'epileptic_records' contiene 198 episodios epilepticos.
# La lista 'normal_records' contiene más de 400 registros normales.
# (En este ejemplo, usaremos números para ilustrar. En tu caso, serán tus objetos o registros.)

# Realizamos un muestreo aleatorio sin reemplazo para seleccionar 198 registros normales.çr
random.seed(42)  # Para reproducibilidad
balanced_normal_records = random.sample(normal_list_ordenada, 198)

# Ahora tenemos 198 registros epilepticos y 198 registros normales.
print("Número de registros epilepticos:", len(epileptic_list_ordenada))
print("Número de registros normales muestreados:", len(balanced_normal_records))

# Opcional: combinar ambas clases en un solo conjunto balanceado
balanced_dataset = {
    "epileptic": epileptic_list_ordenada,
    "normal": balanced_normal_records
}

# Imprimir para verificar
print("\nDatos balanceados:")
print("Episodios epilepticos:", balanced_dataset["epileptic"])
print("Registros normales muestreados:", balanced_dataset["normal"])
# Out:
# Número de registros epilepticos: 141
# Número de registros normales muestreados: 198
#
# Datos balanceados:
# Episodios epilepticos: ['chb01_15.edf', 'chb01_03.edf', 'chb01_16.edf', 'chb01_18.edf', 'chb01_26.edf', 'chb01_04.edf', 'chb01_21.edf', 'chb02_19.edf', 'chb02_16+.edf', 'chb02_16.edf', 'chb03_03.edf', 'chb03_02.edf', 'chb03_34.edf', 'chb03_36.edf', 'chb03_01.edf', 'chb03_35.edf', 'chb03_04.edf', 'chb04_28.edf', 'chb04_05.edf', 'chb04_08.edf', 'chb05_22.edf', 'chb05_13.edf', 'chb05_06.edf', 'chb05_16.edf', 'chb05_17.edf', 'chb06_18.edf', 'chb06_01.edf', 'chb06_13.edf', 'chb06_10.edf', 'chb06_09.edf', 'chb06_04.edf', 'chb06_24.edf', 'chb07_19.edf', 'chb07_13.edf', 'chb07_12.edf', 'chb08_05.edf', 'chb08_02.edf', 'chb08_11.edf', 'chb08_21.edf', 'chb08_13.edf', 'chb09_19.edf', 'chb09_06.edf', 'chb09_08.edf', 'chb10_38.edf', 'chb10_27.edf', 'chb10_31.edf', 'chb10_12.edf', 'chb10_89.edf', 'chb10_20.edf', 'chb10_30.edf', 'chb11_99.edf', 'chb11_92.edf', 'chb11_82.edf', 'chb12_10.edf', 'chb12_33.edf', 'chb12_08.edf', 'chb12_28.edf', 'chb12_11.edf', 'chb12_27.edf', 'chb12_29.edf', 'chb12_23.edf', 'chb12_42.edf', 'chb12_06.edf', 'chb12_38.edf', 'chb12_09.edf', 'chb12_36.edf', 'chb13_55.edf', 'chb13_62.edf', 'chb13_40.edf', 'chb13_21.edf', 'chb13_60.edf', 'chb13_19.edf', 'chb13_59.edf', 'chb13_58.edf', 'chb14_11.edf', 'chb14_04.edf', 'chb14_17.edf', 'chb14_27.edf', 'chb14_03.edf', 'chb14_06.edf', 'chb14_18.edf', 'chb15_52.edf', 'chb15_40.edf', 'chb15_62.edf', 'chb15_28.edf', 'chb15_20.edf', 'chb15_10.edf', 'chb15_49.edf', 'chb15_17.edf', 'chb15_06.edf', 'chb15_22.edf', 'chb15_31.edf', 'chb15_54.edf', 'chb15_15.edf', 'chb15_46.edf', 'chb16_16.edf', 'chb16_14.edf', 'chb16_11.edf', 'chb16_17.edf', 'chb16_18.edf', 'chb16_10.edf', 'chb17a_03.edf', 'chb17a_04.edf', 'chb17b_63.edf', 'chb18_32.edf', 'chb18_29.edf', 'chb18_30.edf', 'chb18_31.edf', 'chb18_36.edf', 'chb18_35.edf', 'chb19_30.edf', 'chb19_28.edf', 'chb19_29.edf', 'chb20_12.edf', 'chb20_15.edf', 'chb20_14.edf', 'chb20_16.edf', 'chb20_68.edf', 'chb20_13.edf', 'chb21_19.edf', 'chb21_22.edf', 'chb21_21.edf', 'chb21_20.edf', 'chb22_38.edf', 'chb22_20.edf', 'chb22_25.edf', 'chb23_08.edf', 'chb23_06.edf', 'chb23_09.edf', 'chb24_17.edf', 'chb24_13.edf', 'chb24_03.edf', 'chb24_21.edf', 'chb24_14.edf', 'chb24_09.edf', 'chb24_11.edf', 'chb24_15.edf', 'chb24_01.edf', 'chb24_06.edf', 'chb24_07.edf', 'chb24_04.edf']
# Registros normales muestreados: ['chb04_10.edf', 'chb01_24.edf', 'chb12_21.edf', 'chb11_25.edf', 'chb09_11.edf', 'chb05_38.edf', 'chb04_38.edf', 'chb03_12.edf', 'chb19_08.edf', 'chb01_30.edf', 'chb01_12.edf', 'chb03_33.edf', 'chb09_16.edf', 'chb10_02.edf', 'chb22_51.edf', 'chb01_41.edf', 'chb08_12.edf', 'chb19_12.edf', 'chb09_14.edf', 'chb20_05.edf', 'chb12_37.edf', 'chb01_06.edf', 'chb05_08.edf', 'chb22_21.edf', 'chb06_05.edf', 'chb23_17.edf', 'chb03_16.edf', 'chb04_29.edf', 'chb21_32.edf', 'chb17c_03.edf', 'chb06_17.edf', 'chb02_34.edf', 'chb02_02.edf', 'chb07_05.edf', 'chb02_09.edf', 'chb07_17.edf', 'chb19_05.edf', 'chb06_12.edf', 'chb13_03.edf', 'chb04_39.edf', 'chb18_04.edf', 'chb01_02.edf', 'chb16_04.edf', 'chb10_15.edf', 'chb11_06.edf', 'chb02_33.edf', 'chb21_16.edf', 'chb07_07.edf', 'chb02_04.edf', 'chb12_20.edf', 'chb05_14.edf', 'chb19_18.edf', 'chb14_42.edf', 'chb14_22.edf', 'chb20_26.edf', 'chb19_24.edf', 'chb07_11.edf', 'chb13_15.edf', 'chb03_09.edf', 'chb15_02.edf', 'chb02_03.edf', 'chb01_10.edf', 'chb15_35.edf', 'chb04_40.edf', 'chb18_08.edf', 'chb05_36.edf', 'chb21_26.edf', 'chb19_04.edf', 'chb04_03.edf', 'chb19_09.edf', 'chb02_01.edf', 'chb22_04.edf', 'chb22_28.edf', 'chb10_14.edf', 'chb14_29.edf', 'chb19_27.edf', 'chb07_01.edf', 'chb03_27.edf', 'chb07_09.edf', 'chb06_07.edf', 'chb04_06.edf', 'chb15_61.edf', 'chb04_22.edf', 'chb15_63.edf', 'chb15_30.edf', 'chb14_02.edf', 'chb02_11.edf', 'chb13_30.edf', 'chb20_30.edf', 'chb03_15.edf', 'chb11_01.edf', 'chb21_23.edf', 'chb04_04.edf', 'chb20_23.edf', 'chb10_22.edf', 'chb20_31.edf', 'chb05_21.edf', 'chb14_19.edf', 'chb15_08.edf', 'chb12_35.edf', 'chb04_16.edf', 'chb15_45.edf', 'chb05_12.edf', 'chb19_19.edf', 'chb18_10.edf', 'chb18_17.edf', 'chb01_38.edf', 'chb04_15.edf', 'chb18_27.edf', 'chb01_11.edf', 'chb18_22.edf', 'chb05_20.edf', 'chb08_18.edf', 'chb04_13.edf', 'chb01_05.edf', 'chb04_02.edf', 'chb12_19.edf', 'chb16_02.edf', 'chb19_23.edf', 'chb18_26.edf', 'chb15_13.edf', 'chb11_61.edf', 'chb08_20.edf', 'chb14_37.edf', 'chb10_03.edf', 'chb03_31.edf', 'chb21_28.edf', 'chb03_20.edf', 'chb04_23.edf', 'chb17a_06.edf', 'chb12_41.edf', 'chb11_19.edf', 'chb04_17.edf', 'chb17c_13.edf', 'chb13_12.edf', 'chb09_12.edf', 'chb13_13.edf', 'chb08_24.edf', 'chb21_17.edf', 'chb19_15.edf', 'chb03_11.edf', 'chb11_13.edf', 'chb11_60.edf', 'chb02_28.edf', 'chb17c_05.edf', 'chb01_32.edf', 'chb02_06.edf', 'chb03_18.edf', 'chb21_14.edf', 'chb03_21.edf', 'chb15_04.edf', 'chb09_10.edf', 'chb13_05.edf', 'chb22_77.edf', 'chb07_04.edf', 'chb07_02.edf', 'chb18_33.edf', 'chb10_17.edf', 'chb11_17.edf', 'chb04_26.edf', 'chb12_32.edf', 'chb01_22.edf', 'chb17a_05.edf', 'chb16_19.edf', 'chb02_13.edf', 'chb20_06.edf', 'chb22_17.edf', 'chb20_08.edf', 'chb14_14.edf', 'chb22_30.edf', 'chb02_31.edf', 'chb21_18.edf', 'chb09_01.edf', 'chb03_37.edf', 'chb20_03.edf', 'chb01_43.edf', 'chb18_34.edf', 'chb11_24.edf', 'chb03_08.edf', 'chb11_14.edf', 'chb02_23.edf', 'chb14_30.edf', 'chb05_28.edf', 'chb20_29.edf', 'chb15_12.edf', 'chb19_25.edf', 'chb04_30.edf', 'chb17b_60.edf', 'chb07_08.edf', 'chb03_24.edf', 'chb11_05.edf', 'chb11_62.edf', 'chb01_33.edf', 'chb13_07.edf', 'chb05_25.edf', 'chb23_07.edf', 'chb01_36.edf', 'chb16_13.edf']

# %%
balanced_normal_records

# %%
# Combina las listas de archivos normales y epilepticos
archivos_validos = set(balanced_normal_records + epileptic_list_ordenada)

# Crear nuevo diccionario filtrado
dict_filtrado = {k: v for k, v in dict_episodios.items() if k in archivos_validos}

# Verificación opcional
print(f"\nNúmero de archivos en el diccionario original: {len(dict_episodios)}")
print(f"Número de archivos en el nuevo diccionario filtrado: {len(dict_filtrado)}")

# Imprimir algunos resultados
for edf_name, episodios in list(dict_filtrado.items())[:5]:  # Solo muestra los primeros 5
    print(f"\nArchivo: {edf_name}")
    for i, epi in enumerate(episodios, 1):
        print(f"  Episodio {i}: Start = {epi['start']}, End = {epi['end']}")
# Out:
# Número de archivos en el diccionario original: 676
# Número de archivos en el nuevo diccionario filtrado: 339
#
# Archivo: chb14_02.edf
#
# Archivo: chb14_03.edf
#   Episodio 1: Start = 1986, End = 2000
#
# Archivo: chb14_04.edf
#   Episodio 1: Start = 1372, End = 1392
#   Episodio 2: Start = 2817, End = 2839
#
# Archivo: chb14_06.edf
#   Episodio 1: Start = 1911, End = 1925
#
# Archivo: chb14_11.edf
#   Episodio 1: Start = 1838, End = 1879

# %%
dict_filtrado

# %% [markdown]
# # Uso de GPU

# %%
import torch

# Seleccionar el dispositivo: 'cuda' si hay GPU, de lo contrario 'cpu'
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Usando dispositivo:", device)

if device.type == 'cuda':
    print("Nombre de la GPU:", torch.cuda.get_device_name(0))
# Out:
# Usando dispositivo: cuda
# Nombre de la GPU: Tesla V100-DGXS-32GB

# %% [markdown]
# # Extracción de ventanas temporales y zero-padding

# %%
import mne
import numpy as np
import os

def resolve_duplicate_channels(raw):
    """
    Resolves duplicate channel names by renaming them with a suffix.
    Uses MNE's rename_channels method to ensure the correct approach.
    """
    ch_names = raw.info['ch_names']

    # Create a dictionary to count duplicates
    unique_ch_names = {}
    new_ch_names = {}

    # Detect and rename duplicates
    for ch in ch_names:
        if ch not in unique_ch_names:
            unique_ch_names[ch] = 1
            new_ch_names[ch] = ch
        else:
            unique_ch_names[ch] += 1
            new_ch_names[ch] = f"{ch}.{unique_ch_names[ch]}"

    # Apply the new names using MNE's rename_channels method
    raw.rename_channels(new_ch_names)

    return raw

def extract_windows_from_segment(eeg_data, start_sec, end_sec, sfreq, window_duration=21):
    """
    Dado un arreglo de forma (n_canales, n_muestras) y un segmento de tiempo (start_sec, end_sec),
    extrae ventanas de 'window_duration' segundos:
      - Convierte start_sec y end_sec a índices.
      - Divide el segmento en múltiples ventanas de 21 segundos.
      - Aplica zero-padding a la última ventana si queda incompleta.

    Retorna una lista de arreglos, cada uno con forma (n_canales, window_duration * sfreq).
    """
    window_samples = int(window_duration * sfreq)

    start_idx = int(start_sec * sfreq)
    end_idx = int(end_sec * sfreq)

    # Recortamos el segmento [start_idx : end_idx] para todos los canales
    segment = eeg_data[:, start_idx:end_idx]  # (n_canales, num_muestras_segmento)
    segment_length = segment.shape[1]

    windows = []

    # Número de ventanas completas que caben en el segmento
    n_full_windows = segment_length // window_samples
    remainder = segment_length % window_samples

    # Extraemos ventanas completas
    for i in range(n_full_windows):
        w_start = i * window_samples
        w_end = (i + 1) * window_samples
        window_data = segment[:, w_start:w_end]  # (n_canales, window_samples)
        windows.append(window_data)

    # Si queda un segmento menor a window_samples, rellenamos con ceros
    if remainder > 0:
        last_part = segment[:, n_full_windows * window_samples:]
        padded = np.zeros((segment.shape[0], window_samples))
        padded[:, :last_part.shape[1]] = last_part
        windows.append(padded)

    return windows

def process_edf_dictionary(dict_episodios, edf_folder, window_duration=21):
    """
    A partir de un diccionario donde:
        dict_episodios[file_name] = [{'start': X, 'end': Y}, ...]  (o lista vacía si no hay episodios)
    Carga cada archivo EDF y:
      - Para cada episodio en la lista, extrae ventanas de 21s (con posible zero-padding).
      - Si la lista de episodios está vacía, extrae solo 1 ventana de 21s desde el inicio (0s).

    Se separan las ventanas por canales, de modo que cada ventana se guarda individualmente
    para cada canal.

    Retorna un diccionario:
        dict_ventanas[file_name] = {
            "channel_1": [(window_1, label), (window_2, label), ...],
            "channel_2": [(window_1, label), (window_2, label), ...],
            ...
        }
    donde cada window_i es un arreglo 1D de longitud window_duration * sfreq, y cada etiqueta es 0 o 1.
    """
    results = {}

    for file_name, episodes in dict_episodios.items():
        edf_path = os.path.join(edf_folder, file_name)

        # Carga la señal completa
        raw = mne.io.read_raw_edf(edf_path, preload=True, verbose=False)

        # Resolviendo nombres duplicados de canales
        raw = resolve_duplicate_channels(raw)

        eeg_data = raw.get_data()  # (n_canales, n_muestras)
        sfreq = raw.info['sfreq']
        n_channels = eeg_data.shape[0]
        window_samples = int(window_duration * sfreq)

        # Inicializamos un diccionario para almacenar ventanas por canal
        channel_windows = {f"channel_{i+1}": [] for i in range(n_channels)}

        if len(episodes) == 0:
            # Archivo sin episodios epilepticos -> extraemos 1 ventana de 21s desde el inicio
            segment_length = eeg_data.shape[1]
            if segment_length < window_samples:
                # Zero-padding si la señal es menor a 21s
                padded = np.zeros((n_channels, window_samples))
                padded[:, :segment_length] = eeg_data[:, :segment_length]
                window_full = padded
            else:
                window_full = eeg_data[:, :window_samples]

            # Separamos la ventana por canales (cada canal es una señal 1D)
            for ch in range(n_channels):
                channel_windows[f"channel_{ch+1}"].append((window_full[ch, :], 0))  # Etiqueta 0
        else:
            # Archivo con 1 o más episodios
            for epi in episodes:
                start_sec = epi['start']
                end_sec = epi['end']
                # Extraemos ventanas para este episodio: cada ventana es (n_channels, window_samples)
                windows_epi = extract_windows_from_segment(eeg_data, start_sec, end_sec, sfreq, window_duration)
                for win in windows_epi:
                    # Separamos cada ventana en sus canales
                    for ch in range(n_channels):
                        channel_windows[f"channel_{ch+1}"].append((win[ch, :], 1))  # Etiqueta 1

        results[file_name] = channel_windows

    return results

if __name__ == "__main__":
    # Carpeta donde se ubican los archivos EDF
    edf_folder = "/home/malvarezb/CHB"

    # Procesar el diccionario para separar las ventanas por canales y agregar etiquetas
    dict_ventanas = process_edf_dictionary(dict_filtrado, edf_folder, window_duration=21)

    # Ejemplo de impresión de resultados
    for file_name, channel_dict in dict_ventanas.items():
        print(f"\nArchivo: {file_name}")
        for channel, windows in channel_dict.items():
            print(f"  {channel}: {len(windows)} ventanas de 21 segundos")
            # Imprimir la forma de la primera ventana de este canal (si existe)
            if windows:
                print(f"    Ejemplo ventana: forma {windows[0][0].shape} (muestras,)")

# %% [markdown]
# # Extracción de episodio epiléptico y ventanas de 21seg para series normales

# %%
import mne
import numpy as np
import os

def resolve_duplicate_channels(raw):
    """
    Resolves duplicate channel names by renaming them with a suffix.
    Uses MNE's rename_channels method to ensure the correct approach.
    """
    ch_names = raw.info['ch_names']
    unique_ch_names = {}
    new_ch_names = {}
    for ch in ch_names:
        if ch not in unique_ch_names:
            unique_ch_names[ch] = 1
            new_ch_names[ch] = ch
        else:
            unique_ch_names[ch] += 1
            new_ch_names[ch] = f"{ch}.{unique_ch_names[ch]}"
    raw.rename_channels(new_ch_names)
    return raw

def process_edf_dictionary(dict_episodios, edf_folder):
    """
    A partir de dict_episodios[file_name] = [{'start': X, 'end': Y}, ...],
    carga cada EDF *lazy* y extrae segmentos sin preload completo.
    """
    results = {}

    for file_name, episodes in dict_episodios.items():
        edf_path = os.path.join(edf_folder, file_name)

        # 1) Carga lazy: no preload completo
        raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
        raw = resolve_duplicate_channels(raw)

        sfreq = raw.info['sfreq']
        n_channels = len(raw.ch_names)
        window_samples = int(230 * sfreq)

        channel_segments = {f"channel_{i+1}": [] for i in range(n_channels)}

        if not episodes:
            # sin episodios → primeros 21 s
            seg = raw.get_data(start=0, stop=window_samples, picks=list(range(n_channels)))
            # pad si hace falta
            if seg.shape[1] < window_samples:
                pad = np.zeros((n_channels, window_samples), dtype=seg.dtype)
                pad[:, :seg.shape[1]] = seg
                seg = pad
            for ch in range(n_channels):
                channel_segments[f"channel_{ch+1}"].append((seg[ch], 0))
        else:
            # con episodios → ventanas exactas (sin contexto adicional)
            for epi in episodes:
                start_idx = int(epi['start'] * sfreq)
                end_idx   = int(epi['end']   * sfreq)
                # lee sólo del EDF ese intervalo
                seg = raw.get_data(start=start_idx, stop=end_idx, picks=list(range(n_channels)))
                # pad/recorte si no coincide con window_samples
                if seg.shape[1] < window_samples:
                    pad = np.zeros((n_channels, window_samples), dtype=seg.dtype)
                    pad[:, :seg.shape[1]] = seg
                    seg = pad
                else:
                    seg = seg[:, :window_samples]
                for ch in range(n_channels):
                    channel_segments[f"channel_{ch+1}"].append((seg[ch], 1))

        results[file_name] = channel_segments
        raw.close()

    return results

if __name__ == "__main__":
    edf_folder = "/mnt/DGX0Raid/databases/CHB_data/CHB"
    dict_ventanas = process_edf_dictionary(dict_filtrado, edf_folder)
    for file_name, channel_dict in dict_ventanas.items():
        print(f"\nArchivo: {file_name}")
        for channel, segments in channel_dict.items():
            print(f"  {channel}: {len(segments)} segmentos")
            if segments:
                print(f"    Ejemplo segmento: forma {segments[0][0].shape} (muestras,)")

# %% [markdown]
# # Extracción de ventanas de 21 segundos en señales epilépticas y normales

# %%
import mne
import numpy as np
import os

def resolve_duplicate_channels(raw):
    """
    Resolves duplicate channel names by renaming them with a suffix.
    Uses MNE's rename_channels method to ensure the correct approach.
    """
    ch_names = raw.info['ch_names']

    # Create a dictionary to count duplicates
    unique_ch_names = {}
    new_ch_names = {}

    # Detect and rename duplicates
    for ch in ch_names:
        if ch not in unique_ch_names:
            unique_ch_names[ch] = 1
            new_ch_names[ch] = ch
        else:
            unique_ch_names[ch] += 1
            new_ch_names[ch] = f"{ch}.{unique_ch_names[ch]}"

    # Apply the new names using MNE's rename_channels method
    raw.rename_channels(new_ch_names)

    return raw

def load_edf_lazy(edf_path):
    """
    Lazily loads the EDF file when needed.
    """
    # This function will return the raw MNE object for lazy loading
    raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
    return raw

def get_segment(raw, start_sec, end_sec, window_samples, sfreq, n_channels):
    """
    Helper function to load a specific segment of the data lazily.
    """
    start_idx = int(start_sec * sfreq)
    end_idx = int(end_sec * sfreq)

    # Aseguramos que el segmento sea de 21 segundos
    segment_start = max(0, start_idx)
    segment_end = min(raw.n_times, segment_start + window_samples)

    # Extraer los datos del segmento correspondiente
    segment = raw.get_data(start=segment_start, stop=segment_end)  # (n_canales, num_muestras_segmento)

    # Si el segmento no es de 21 segundos, rellenamos con ceros
    if segment.shape[1] < window_samples:
        padded = np.zeros((n_channels, window_samples))
        padded[:, :segment.shape[1]] = segment
        segment = padded

    return segment

def process_edf_dictionary(dict_episodios, edf_folder):
    """
    A partir de un diccionario donde:
        dict_episodios[file_name] = [{'start': X, 'end': Y}, ...]  (o lista vacía si no hay episodios)
    Carga cada archivo EDF de manera lazy y:
      - Para cada episodio en la lista, almacena el segmento completo de 21 segundos.
      - Si la lista de episodios está vacía, extrae los primeros 21 segundos desde el inicio.

    Se retornan los segmentos completos de cada canal junto con la etiqueta correspondiente (0 para normal, 1 para epiléptico).
    """
    results = {}

    for file_name, episodes in dict_episodios.items():
        edf_path = os.path.join(edf_folder, file_name)

        # Carga la señal de manera lazy
        raw = load_edf_lazy(edf_path)

        # Resolviendo nombres duplicados de canales
        raw = resolve_duplicate_channels(raw)

        # Información sobre el archivo
        eeg_data = raw.get_data()  # (n_canales, n_muestras)
        sfreq = raw.info['sfreq']
        n_channels = eeg_data.shape[0]
        window_samples = int(21 * sfreq)  # Tomamos siempre 21 segundos

        # Inicializamos un diccionario para almacenar los segmentos por canal
        channel_segments = {f"channel_{i+1}": [] for i in range(n_channels)}

        if len(episodes) == 0:
            # Archivo sin episodios epilépticos -> extraemos solo los primeros 21 segundos desde el inicio
            segment_full = get_segment(raw, 0, 21, window_samples, sfreq, n_channels)

            # Separamos el segmento por canales (cada canal es una señal 1D)
            for ch in range(n_channels):
                channel_segments[f"channel_{ch+1}"].append((segment_full[ch, :], 0))  # Etiqueta 0 (normal)
        else:
            # Archivo con 1 o más episodios
            for epi in episodes:
                start_sec = epi['start']
                end_sec = epi['end']

                segment = get_segment(raw, start_sec, end_sec, window_samples, sfreq, n_channels)

                # Separamos el segmento completo por canales
                for ch in range(n_channels):
                    # Etiqueta 1 para evento epiléptico, 0 para normal
                    label = 1 if epi else 0
                    channel_segments[f"channel_{ch+1}"].append((segment[ch, :], label))

        results[file_name] = channel_segments

    return results

if __name__ == "__main__":
    # Carpeta donde se ubican los archivos EDF
    edf_folder = "/mnt/DGX0Raid/databases/CHB_data/CHB"

    # Procesar el diccionario para separar los segmentos por canales y agregar etiquetas
    dict_ventanas = process_edf_dictionary(dict_filtrado, edf_folder)

    # Ejemplo de impresión de resultados
    for file_name, channel_dict in dict_ventanas.items():
        print(f"\nArchivo: {file_name}")
        for channel, segments in channel_dict.items():
            print(f"  {channel}: {len(segments)} segmentos")
            # Imprimir la forma del primer segmento de este canal (si existe)
            if segments:
                print(f"    Ejemplo segmento: forma {segments[0][0].shape} (muestras,)")
# Out:
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Scaling factor is not defined in following channels:
# --0, --1, --2, --3, --4
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Scaling factor is not defined in following channels:
# --0, --1, --2, --3, --4
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Scaling factor is not defined in following channels:
# --0, --1, --2, --3, --4
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Scaling factor is not defined in following channels:
# --0, --1, --2, --3, --4
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Scaling factor is not defined in following channels:
# --0, --1, --2, --3, --4
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Scaling factor is not defined in following channels:
# --0, --1, --2, --3, --4
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Scaling factor is not defined in following channels:
# --0, --1, --2, --3, --4
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Scaling factor is not defined in following channels:
# --0, --1, --2, --3, --4
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Scaling factor is not defined in following channels:
# --0, --1, --2, --3, --4
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Scaling factor is not defined in following channels:
# --0, --1, --2, --3, --4
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Scaling factor is not defined in following channels:
# --0, --1, --2, --3, --4
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Scaling factor is not defined in following channels:
# --0, --1, --2, --3, --4
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Scaling factor is not defined in following channels:
# --0, --1, --2, --3, --4
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Scaling factor is not defined in following channels:
# --0, --1, --2, --3, --4
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Scaling factor is not defined in following channels:
# --0, --1, --2, --3, --4
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Scaling factor is not defined in following channels:
# --0, --1, --2, --3, --4
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Scaling factor is not defined in following channels:
# --0, --1, --2, --3
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Scaling factor is not defined in following channels:
# --0, --1, --2, --3
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Scaling factor is not defined in following channels:
# --0, --1, --2, --3
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Scaling factor is not defined in following channels:
# --0, --1, --2, --3
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Scaling factor is not defined in following channels:
# --0, --1, --2, --3
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Scaling factor is not defined in following channels:
# --0, --1, --2, --3, --4
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Scaling factor is not defined in following channels:
# --0, --1, --2, --3, --4
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Scaling factor is not defined in following channels:
# --0, --1, --2, --3
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Scaling factor is not defined in following channels:
# --0, --1, --2, --3
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Scaling factor is not defined in following channels:
# --0, --1, --2, --3, --4
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Scaling factor is not defined in following channels:
# --0, --1, --2, --3, --4
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Scaling factor is not defined in following channels:
# --0, --1, --2, --3, --4
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Scaling factor is not defined in following channels:
# --0, --1, --2, --3, --4
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Scaling factor is not defined in following channels:
# --0, --1, --2, --3, --4
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Scaling factor is not defined in following channels:
# --0, --1, --2, --3, --4
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Scaling factor is not defined in following channels:
# --0, --1, --2, --3, --4
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Scaling factor is not defined in following channels:
# --0, --1, --2, --3, --4
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Scaling factor is not defined in following channels:
# --0, --1, --2, --3, --4
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Scaling factor is not defined in following channels:
# --0, --1, --2, --3, --4
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Scaling factor is not defined in following channels:
# --0, --1, --2, --3, --4
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Scaling factor is not defined in following channels:
# --0, --1, --2, --3, --4
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Scaling factor is not defined in following channels:
# --0, --1, --2, --3, --4
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Scaling factor is not defined in following channels:
# --0, --1, --2, --3, --4
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Scaling factor is not defined in following channels:
# --0, --1, --2, --3, --4
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Scaling factor is not defined in following channels:
# --0, --1, --2, --3, --4
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Scaling factor is not defined in following channels:
# --0, --1, --2, --3, --4
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'.', 'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'.', 'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'.', 'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'.', 'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'.', 'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'.', 'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'.', 'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'.', 'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'.', 'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'.', 'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'.', 'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'.', 'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'.', 'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'.', 'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'.', 'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'.', 'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'.', 'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'.', 'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'.', 'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'.', 'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'.', 'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'.', 'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'.', 'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'.', 'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'.', 'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'.', 'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'.', 'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'.', 'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'.', 'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'.', 'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Scaling factor is not defined in following channels:
# --0, --1, --2, --3, --4
#   raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
# <ipython-input-8-f18ec28d622b>:35: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8', '-'}. Applying running numbers for duplicates.
# ...
#   channel_17: 3 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_18: 3 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_19: 3 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_20: 3 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_21: 3 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_22: 3 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_23: 3 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#
# Archivo: chb24_06.edf
#   channel_1: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_2: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_3: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_4: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_5: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_6: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_7: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_8: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_9: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_10: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_11: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_12: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_13: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_14: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_15: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_16: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_17: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_18: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_19: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_20: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_21: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_22: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_23: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#
# Archivo: chb24_07.edf
#   channel_1: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_2: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_3: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_4: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_5: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_6: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_7: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_8: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_9: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_10: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_11: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_12: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_13: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_14: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_15: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_16: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_17: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_18: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_19: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_20: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_21: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_22: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_23: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#
# Archivo: chb24_09.edf
#   channel_1: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_2: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_3: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_4: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_5: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_6: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_7: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_8: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_9: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_10: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_11: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_12: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_13: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_14: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_15: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_16: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_17: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_18: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_19: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_20: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_21: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_22: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_23: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#
# Archivo: chb24_11.edf
#   channel_1: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_2: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_3: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_4: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_5: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_6: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_7: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_8: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_9: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_10: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_11: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_12: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_13: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_14: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_15: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_16: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_17: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_18: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_19: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_20: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_21: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_22: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_23: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#
# Archivo: chb24_13.edf
#   channel_1: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_2: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_3: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_4: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_5: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_6: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_7: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_8: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_9: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_10: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_11: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_12: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_13: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_14: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_15: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_16: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_17: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_18: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_19: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_20: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_21: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_22: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_23: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#
# Archivo: chb24_14.edf
#   channel_1: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_2: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_3: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_4: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_5: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_6: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_7: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_8: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_9: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_10: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_11: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_12: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_13: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_14: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_15: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_16: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_17: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_18: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_19: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_20: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_21: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_22: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_23: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#
# Archivo: chb24_15.edf
#   channel_1: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_2: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_3: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_4: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_5: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_6: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_7: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_8: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_9: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_10: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_11: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_12: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_13: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_14: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_15: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_16: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_17: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_18: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_19: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_20: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_21: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_22: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_23: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#
# Archivo: chb24_17.edf
#   channel_1: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_2: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_3: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_4: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_5: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_6: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_7: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_8: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_9: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_10: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_11: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_12: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_13: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_14: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_15: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_16: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_17: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_18: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_19: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_20: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_21: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_22: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_23: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#
# Archivo: chb24_21.edf
#   channel_1: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_2: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_3: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_4: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_5: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_6: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_7: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_8: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_9: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_10: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_11: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_12: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_13: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_14: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_15: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_16: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_17: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_18: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_19: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_20: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_21: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_22: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)
#   channel_23: 1 segmentos
#     Ejemplo segmento: forma (5376,) (muestras,)

# %%
dict_ventanas

# %% [markdown]
# # Kshape con generadores

# %%
import numpy as np
import cupy as cp  # For GPU operations
from tslearn.preprocessing import TimeSeriesScalerMeanVariance
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
import pandas as pd
import matplotlib.pyplot as plt
from tslearn.utils import to_time_series_dataset
from sklearn.model_selection import train_test_split, cross_val_score
from tslearn.clustering import KShape

# Función para preparar los datos de KShape
def prepare_kshape_data(dict_ventanas, target_length=5376):
    """
    Convierte los segmentos de EEG en un dataset adecuado para KShape de manera perezosa (lazy).
    Los segmentos se rellenan o recortan a una longitud fija.
    """
    print("Preparing KShape data...")

    # Generador para procesar los segmentos
    for file_name, channel_dict in dict_ventanas.items():
        for channel, segments in channel_dict.items():
            for segment, label in segments:
                # Rellenar o recortar el segmento a la longitud fija
                if len(segment) < target_length:
                    # Zero-padding si el segmento es más corto que la longitud objetivo
                    padded_segment = np.pad(segment, (0, target_length - len(segment)), 'constant')
                else:
                    # Recortar si el segmento es más largo que la longitud objetivo
                    padded_segment = segment[:target_length]

                # Convertir el segmento de NumPy a CuPy para procesamiento en GPU
                padded_segment_gpu = cp.array(padded_segment)

                # Devolver el segmento procesado y su etiqueta
                yield padded_segment_gpu, label

    print("KShape data prepared.")

# Función para cargar y procesar los datos (usando el diccionario dict_ventanas generado desde los datos EEG)
def process_kshape_data(dict_ventanas):
    print("Processing KShape data...")

    # Inicializamos las listas para almacenar los segmentos y las etiquetas
    all_segments = []
    all_labels = []

    # Usar el generador para obtener los segmentos
    for segment, label in prepare_kshape_data(dict_ventanas):
        all_segments.append(segment)
        all_labels.append(label)

    # Convertir las listas de segmentos y etiquetas en arrays
    # Usamos .get() para convertir explícitamente de CuPy a NumPy
    # Convertir las listas de segmentos y etiquetas en arrays
    all_segments = np.array([seg.get() for seg in all_segments])  # Convertir de CuPy a NumPy
    all_labels = np.array(all_labels)

    # Verificar la forma del array de segmentos para asegurarse de que es homogéneo
    if all_segments.ndim != 2:
        raise ValueError(f"Los segmentos no tienen una forma homogénea. Forma detectada: {all_segments.shape}")

    # Escalar los datos usando TimeSeriesScalerMeanVariance
    scaler = TimeSeriesScalerMeanVariance(mu=0., std=1.)
    all_segments_scaled = scaler.fit_transform(all_segments)

    # Dividir los datos para entrenamiento y prueba (80-20)
    X_train, X_test, y_train, y_test = train_test_split(all_segments_scaled, all_labels, test_size=0.2, random_state=42)

    print(f"Data split into training and testing sets. Training size: {len(X_train)}, Testing size: {len(X_test)}")
    print("Data scaled.")

    return X_train, X_test, y_train, y_test

# Ejemplo de cómo usar la función
dict_ventanas = process_edf_dictionary(dict_filtrado, edf_folder)
X_train_scaled, X_test_scaled, y_train, y_test = process_kshape_data(dict_ventanas)

# Experiment with different values for tol and n_init
tol_values = [1e-4, 1e-5, 1e-6, 1e-7, 1e-8]
n_init_values = [1, 3, 5, 7, 10]

# Initialize the best performance tracking variables
best_f1_score = -1
best_tol = None
best_n_init = None

# Perform cross-validation with 10 folds
for tol in tol_values:
    for n_init in n_init_values:
        model = KShape(n_clusters=2, n_init=n_init, tol=tol, random_state=0)

        # Perform cross-validation with 10 folds
        cv_scores = cross_val_score(model, X_train_scaled, y_train, cv=10, scoring='accuracy')
        mean_cv_score = np.mean(cv_scores)

        print(f"tolerance: {tol} | n_init: {n_init} | Mean CV Accuracy: {mean_cv_score:.4f}")

        if mean_cv_score > best_f1_score:
            best_f1_score = mean_cv_score
            best_tol = tol
            best_n_init = n_init

# Train the model with the best parameters
print(f"\nBest parameters found - tol: {best_tol}, n_init: {best_n_init}")
model = KShape(n_clusters=2, n_init=best_n_init, tol=best_tol, random_state=0)
model.fit(X_train_scaled)

# Predictions
y_pred_train = model.predict(X_train_scaled)
y_pred_test = model.predict(X_test_scaled)

# Evaluation
acc = accuracy_score(y_train, y_pred_train)
precision = precision_score(y_train, y_pred_train, average='weighted')
recall = recall_score(y_train, y_pred_train, average='weighted')
f1 = f1_score(y_train, y_pred_train, average='weighted')

print(f"\nAccuracy: {acc:.4f} | Precision: {precision:.4f} | Recall: {recall:.4f} | F1-score: {f1:.4f}")

# Confusion matrix and classification report
conf_matrix = confusion_matrix(y_train, y_pred_train)
print("\nConfusion Matrix Train:")
print(conf_matrix)
print("\nClassification Report Train:")
print(classification_report(y_train, y_pred_train))

# Confusion matrix and classification report
conf_matrix = confusion_matrix(y_test, y_pred_test)
print("\nConfusion Matrix Test:")
print(conf_matrix)
print("\nClassification Report Test:")
print(classification_report(y_test, y_pred_test))

# Visualization of signals by cluster with centroids in red
centroids = model.cluster_centers_

plt.figure(figsize=(15, 6))
for cluster_idx in range(2):  # Only 2 clusters
    plt.subplot(1, 2, cluster_idx + 1)
    cluster_signals = X_test_scaled[y_pred_test == cluster_idx]

    for ts in cluster_signals:
        plt.plot(ts.ravel(), color='gray', alpha=0.4)

    plt.plot(centroids[cluster_idx].ravel(), color='red', linewidth=2, label='Centroid')
    plt.title(f'Cluster {cluster_idx}')
    plt.xlabel('Time')
    plt.ylabel('Amplitude')
    plt.legend()

plt.tight_layout()
plt.suptitle("Signals by Cluster with Centroids in Red", y=1.02, fontsize=16)
plt.show()

# %% [markdown]
# # Time Series K-means

# %%
import numpy as np
import cupy as cp  # For GPU operations
from tslearn.clustering import TimeSeriesKMeans
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt

# Function to prepare Time Series KMeans data from the EEG windows using CuPy for GPU support
def prepare_kmeans_data(dict_ventanas):
    """
    Converts the windows from each channel into a time-series dataset suitable for KMeans clustering.
    """
    all_windows = []
    all_labels = []

    # Flatten all windows into one list, where each window is a time series
    for file_name, channel_dict in dict_ventanas.items():
        for channel, windows in channel_dict.items():
            for window, label in windows:
                all_windows.append(window)
                all_labels.append(label)

    # Convert the windows into a time-series dataset (tslearn compatible)
    all_windows = np.array(all_windows)

    # Convert numpy arrays to CuPy arrays for GPU processing
    all_windows_gpu = cp.array(all_windows)

    # Explicitly convert the CuPy array to NumPy before passing it to tslearn
    return all_windows_gpu.get(), np.array(all_labels)  # Return the windows and labels separately


# Function to load and process the data (using the dict_ventanas generated from EEG data)
def process_kmeans_data(dict_ventanas):
    # Prepare the Time Series KMeans data from the EEG windows and extract labels
    X, labels = prepare_kmeans_data(dict_ventanas)

    # Split the data for training and testing (using a 80-20 split)
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, labels, test_size=0.2, random_state=42)

    return X_train, X_test, y_train, y_test


# Prepare the Time Series KMeans data
X_train, X_test, y_train, y_test = process_kmeans_data(dict_ventanas)

# Initialize the TimeSeriesKMeans model
model = TimeSeriesKMeans(n_clusters=2, metric="euclidean", verbose=True)

# Fit the model on the training data
y_pred_train = model.fit_predict(X_train)

# Predictions on the test data
y_pred_test = model.predict(X_test)

# Evaluation
acc = accuracy_score(y_test, y_pred_test)
precision = precision_score(y_test, y_pred_test, average='weighted')
recall = recall_score(y_test, y_pred_test, average='weighted')
f1 = f1_score(y_test, y_pred_test, average='weighted')

print(f"\nAccuracy: {acc:.4f} | Precision: {precision:.4f} | Recall: {recall:.4f} | F1-score: {f1:.4f}")

# Confusion matrix and classification report
conf_matrix = confusion_matrix(y_test, y_pred_test)
print("\nConfusion Matrix:")
print(conf_matrix)
print("\nClassification Report:")
print(classification_report(y_test, y_pred_test))

# Visualization of signals by cluster with centroids in red
centroids = model.cluster_centers_

plt.figure(figsize=(15, 6))
for cluster_idx in range(2):  # Only 2 clusters
    plt.subplot(1, 2, cluster_idx + 1)
    cluster_signals = X_test[y_pred_test == cluster_idx]

    for ts in cluster_signals:
        plt.plot(ts.ravel(), color='gray', alpha=0.4)

    plt.plot(centroids[cluster_idx].ravel(), color='red', linewidth=2, label='Centroid')
    plt.title(f'Cluster {cluster_idx}')
    plt.xlabel('Time')
    plt.ylabel('Amplitude')
    plt.legend()

plt.tight_layout()
plt.suptitle("Signals by Cluster with Centroids in Red", y=1.02, fontsize=16)
plt.show()

# %%
from tslearn.clustering import TimeSeriesKMeans

print("Time Series Kmeans")

# Perform cross-validation with 10 folds
for tol in tol_values:
    for n_init in n_init_values:
        model = TimeSeriesKMeans(n_clusters=2, metric="euclidean", n_init=n_init, tol=tol)

        # Perform cross-validation with 10 folds
        cv_scores = cross_val_score(model, X_train_scaled, y_train, cv=10, scoring='accuracy')
        mean_cv_score = np.mean(cv_scores)

        print(f"tolerance: {tol} | n_init: {n_init} | Mean CV Accuracy: {mean_cv_score:.4f}")

        if mean_cv_score > best_f1_score:
            best_f1_score = mean_cv_score
            best_tol = tol
            best_n_init = n_init

# Train the model with the best parameters
print(f"\nBest parameters found - tol: {best_tol}, n_init: {best_n_init}")
model = TimeSeriesKMeans(n_clusters=2, metric="euclidean", n_init=best_n_init, tol=best_tol)
model.fit(X_train_scaled)

# Predictions
y_pred_train = model.predict(X_train_scaled)
y_pred_test = model.predict(X_test_scaled)

# Evaluation
acc = accuracy_score(y_train, y_pred_train)
precision = precision_score(y_train, y_pred_train, average='weighted')
recall = recall_score(y_train, y_pred_train, average='weighted')
f1 = f1_score(y_train, y_pred_train, average='weighted')

print(f"\nAccuracy: {acc:.4f} | Precision: {precision:.4f} | Recall: {recall:.4f} | F1-score: {f1:.4f}")

# Confusion matrix and classification report
conf_matrix = confusion_matrix(y_train, y_pred_train)
print("\nConfusion Matrix Train:")
print(conf_matrix)
print("\nClassification Report Train:")
print(classification_report(y_train, y_pred_train))

# Confusion matrix and classification report
conf_matrix = confusion_matrix(y_test, y_pred_test)
print("\nConfusion Matrix Test:")
print(conf_matrix)
print("\nClassification Report Test:")
print(classification_report(y_test, y_pred_test))

# Visualization of signals by cluster with centroids in red
centroids = model.cluster_centers_

plt.figure(figsize=(15, 6))
for cluster_idx in range(2):  # Only 2 clusters
    plt.subplot(1, 2, cluster_idx + 1)
    cluster_signals = X_test_scaled[y_pred_test == cluster_idx]

    for ts in cluster_signals:
        plt.plot(ts.ravel(), color='gray', alpha=0.4)

    plt.plot(centroids[cluster_idx].ravel(), color='red', linewidth=2, label='Centroid')
    plt.title(f'Cluster {cluster_idx}')
    plt.xlabel('Time')
    plt.ylabel('Amplitude')
    plt.legend()

plt.tight_layout()
plt.suptitle("Signals by Cluster with Centroids in Red", y=1.02, fontsize=16)
plt.show()
